# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from torch.autograd import Variable

# %%
if torch.cuda.is_available():
   DEVICE = torch.device("cuda")
else:
   DEVICE = torch.device("cpu")

print(DEVICE)
# Out:
# cpu

# %%
torch.manual_seed(1)

# %%
# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.Compose([
                                           
                                                transforms.ToTensor(),
                                               
                                                ]),  
                                           download=True,
                                          )


test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.Compose([
                                                
                                                transforms.ToTensor(),
                                          
                                                ])
                                         )

print("train_dataset size:", len(train_dataset),"\ntest_dataset size:", len(test_dataset))
# Out:
# train_dataset size: 60000
# test_dataset size: 10000

# %%
# Label Randomizer

randomLabel = torch.tensor(np.random.randint(0, 10, (len(train_dataset)),))
train_dataset.targets = randomLabel

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=100, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=100, 
                                          shuffle=False)

examples = iter(train_loader)
example_data, example_targets = examples.next()

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(example_data[i][0], cmap='gray')
    plt.title("Actual Val: {}".format(example_targets[i]))
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
class RMNIST(nn.Module):
    def __init__(self):
        super(RMNIST, self).__init__()
        
        self.fc1 = nn.Linear(784, 500)
        self.fc2 = nn.Linear(500, 10)
        

    def forward(self, x):

        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def train(model, optimizer, epoch, train_loader, interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    n_samples = 0
    for i, (data, target) in enumerate(train_loader):
        
        #if (i+1)%interval == 0 : print(i+1)  
        data, target = Variable(data), Variable(target)
        
        optimizer.zero_grad()

        # Forward propagation
        prediction = model(data)
        loss = loss_fn(prediction, target)
        
        #Backward propagation
        loss.backward()
        
        optimizer.step()

        _, predicted = torch.max(prediction.data, 1)
        n_samples += target.size(0)
        n_correct += (predicted == target).sum().item()
        acc = 100.0 * n_correct / n_samples
        
        
        if i % interval == 0:
            print (f'Train Log:Epoch: {epoch}, Step [{i+1}/{len(train_loader.dataset)}], TrainLoss: {loss.item():.4f}')
    return loss.data, round(acc,2)

# %%
def test(model, epoch, test_loader):
    test_load = test_loader
    model.eval()
    n_correct = 0
    n_samples = 0
    testLoss = 0
    count = 0
    
    with torch.no_grad():
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
    
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
           
            _,predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            count += 1
            n_correct += (predicted == labels).sum().item()
    
        Test_loss = testLoss/count
        netTest_acc1 = 100.0 * n_correct / n_samples
        print(f'Accuracy of the network on the test images: {netTest_acc1}% & Test Loss: {Test_loss}')
    return netTest_acc1, Test_loss

#torch.manual_seed(1)

rmnist = RMNIST()
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rmnist.parameters(), lr=0.0001)

a=[]
for i in rmnist.parameters():
    a.append(torch.numel(i))
print('Total no of parameters in Model 1:', np.sum(a),)

train_loss_arr = []

test_loss_arr = []

epochArr = []
epochs = 1000
interval = 500
for epoch in range(1, epochs + 1):
    epochArr.append(epoch)
    loss, acc = train(rmnist, optimizer, epoch, train_loader, interval)
    train_loss_arr.append(loss.detach().numpy())
    testAcc,testloss = test(rmnist, epoch, test_loader)
    test_loss_arr.append(testloss)

    
#Plotting Train Vs Test Loss

plt.plot(epochArr,train_loss_arr,color="Blue")
plt.plot(epochArr,test_loss_arr,color="red")
plt.legend(['Train Loss','Test Loss'],loc="upper right")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("random labels train vs test loss",color = "green")

plt.show()
# Out:
# Total no of parameters in Model 1: 397510
# Train Log:Epoch: 1, Step [1/60000], TrainLoss: 2.3029
# Train Log:Epoch: 1, Step [501/60000], TrainLoss: 2.2962
# Accuracy of the network on the test images: 11.33% & Test Loss: 2.304582335948944
# Train Log:Epoch: 2, Step [1/60000], TrainLoss: 2.3005
# Train Log:Epoch: 2, Step [501/60000], TrainLoss: 2.3037
# Accuracy of the network on the test images: 7.23% & Test Loss: 2.3129026532173156
# Train Log:Epoch: 3, Step [1/60000], TrainLoss: 2.3010
# Train Log:Epoch: 3, Step [501/60000], TrainLoss: 2.3048
# Accuracy of the network on the test images: 7.23% & Test Loss: 2.3076931929588316
# Train Log:Epoch: 4, Step [1/60000], TrainLoss: 2.3012
# Train Log:Epoch: 4, Step [501/60000], TrainLoss: 2.2812
# Accuracy of the network on the test images: 9.12% & Test Loss: 2.3149949502944946
# Train Log:Epoch: 5, Step [1/60000], TrainLoss: 2.2848
# Train Log:Epoch: 5, Step [501/60000], TrainLoss: 2.3001
# Accuracy of the network on the test images: 8.85% & Test Loss: 2.3181060934066773
# Train Log:Epoch: 6, Step [1/60000], TrainLoss: 2.2931
# Train Log:Epoch: 6, Step [501/60000], TrainLoss: 2.2723
# Accuracy of the network on the test images: 9.11% & Test Loss: 2.3122935056686402
# Train Log:Epoch: 7, Step [1/60000], TrainLoss: 2.2803
# Train Log:Epoch: 7, Step [501/60000], TrainLoss: 2.2593
# Accuracy of the network on the test images: 8.28% & Test Loss: 2.3165363121032714
# Train Log:Epoch: 8, Step [1/60000], TrainLoss: 2.2764
# Train Log:Epoch: 8, Step [501/60000], TrainLoss: 2.2859
# Accuracy of the network on the test images: 7.64% & Test Loss: 2.3245478677749634
# Train Log:Epoch: 9, Step [1/60000], TrainLoss: 2.2549
# Train Log:Epoch: 9, Step [501/60000], TrainLoss: 2.2970
# Accuracy of the network on the test images: 9.37% & Test Loss: 2.317366805076599
# Train Log:Epoch: 10, Step [1/60000], TrainLoss: 2.2548
# Train Log:Epoch: 10, Step [501/60000], TrainLoss: 2.2650
# Accuracy of the network on the test images: 9.75% & Test Loss: 2.3231398844718933
# Train Log:Epoch: 11, Step [1/60000], TrainLoss: 2.2576
# Train Log:Epoch: 11, Step [501/60000], TrainLoss: 2.2430
# Accuracy of the network on the test images: 10.05% & Test Loss: 2.3209178709983824
# Train Log:Epoch: 12, Step [1/60000], TrainLoss: 2.2374
# Train Log:Epoch: 12, Step [501/60000], TrainLoss: 2.2395
# Accuracy of the network on the test images: 9.04% & Test Loss: 2.3358625864982603
# Train Log:Epoch: 13, Step [1/60000], TrainLoss: 2.2366
# Train Log:Epoch: 13, Step [501/60000], TrainLoss: 2.2858
# Accuracy of the network on the test images: 9.73% & Test Loss: 2.3123486018180848
# Train Log:Epoch: 14, Step [1/60000], TrainLoss: 2.2550
# Train Log:Epoch: 14, Step [501/60000], TrainLoss: 2.2992
# Accuracy of the network on the test images: 8.93% & Test Loss: 2.3334426569938658
# Train Log:Epoch: 15, Step [1/60000], TrainLoss: 2.2260
# Train Log:Epoch: 15, Step [501/60000], TrainLoss: 2.2424
# Accuracy of the network on the test images: 9.09% & Test Loss: 2.342065808773041
# Train Log:Epoch: 16, Step [1/60000], TrainLoss: 2.2125
# Train Log:Epoch: 16, Step [501/60000], TrainLoss: 2.2025
# Accuracy of the network on the test images: 9.94% & Test Loss: 2.3307572841644286
# Train Log:Epoch: 17, Step [1/60000], TrainLoss: 2.1803
# Train Log:Epoch: 17, Step [501/60000], TrainLoss: 2.2394
# Accuracy of the network on the test images: 10.28% & Test Loss: 2.3241026306152346
# Train Log:Epoch: 18, Step [1/60000], TrainLoss: 2.2130
# Train Log:Epoch: 18, Step [501/60000], TrainLoss: 2.1963
# Accuracy of the network on the test images: 8.5% & Test Loss: 2.3574739789962766
# Train Log:Epoch: 19, Step [1/60000], TrainLoss: 2.2197
# Train Log:Epoch: 19, Step [501/60000], TrainLoss: 2.2298
# Accuracy of the network on the test images: 9.05% & Test Loss: 2.349405057430267
# Train Log:Epoch: 20, Step [1/60000], TrainLoss: 2.1761
# Train Log:Epoch: 20, Step [501/60000], TrainLoss: 2.2366
# Accuracy of the network on the test images: 9.5% & Test Loss: 2.3415449762344362
# Train Log:Epoch: 21, Step [1/60000], TrainLoss: 2.1824
# Train Log:Epoch: 21, Step [501/60000], TrainLoss: 2.1836
# Accuracy of the network on the test images: 8.89% & Test Loss: 2.3474555087089537
# Train Log:Epoch: 22, Step [1/60000], TrainLoss: 2.1918
# Train Log:Epoch: 22, Step [501/60000], TrainLoss: 2.1739
# Accuracy of the network on the test images: 9.51% & Test Loss: 2.351159620285034
# Train Log:Epoch: 23, Step [1/60000], TrainLoss: 2.2002
# Train Log:Epoch: 23, Step [501/60000], TrainLoss: 2.1599
# Accuracy of the network on the test images: 9.04% & Test Loss: 2.35774845123291
# Train Log:Epoch: 24, Step [1/60000], TrainLoss: 2.1892
# Train Log:Epoch: 24, Step [501/60000], TrainLoss: 2.2188
# Accuracy of the network on the test images: 9.85% & Test Loss: 2.3512225461006167
# Train Log:Epoch: 25, Step [1/60000], TrainLoss: 2.1611
# Train Log:Epoch: 25, Step [501/60000], TrainLoss: 2.1492
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.3574606013298034
# Train Log:Epoch: 26, Step [1/60000], TrainLoss: 2.2210
# Train Log:Epoch: 26, Step [501/60000], TrainLoss: 2.1300
# Accuracy of the network on the test images: 9.54% & Test Loss: 2.3686027836799624
# Train Log:Epoch: 27, Step [1/60000], TrainLoss: 2.1352
# Train Log:Epoch: 27, Step [501/60000], TrainLoss: 2.1401
# Accuracy of the network on the test images: 10.09% & Test Loss: 2.356083080768585
# Train Log:Epoch: 28, Step [1/60000], TrainLoss: 2.1350
# Train Log:Epoch: 28, Step [501/60000], TrainLoss: 2.1461
# Accuracy of the network on the test images: 10.32% & Test Loss: 2.3566887259483336
# Train Log:Epoch: 29, Step [1/60000], TrainLoss: 2.0600
# Train Log:Epoch: 29, Step [501/60000], TrainLoss: 2.1916
# Accuracy of the network on the test images: 9.34% & Test Loss: 2.366329379081726
# Train Log:Epoch: 30, Step [1/60000], TrainLoss: 2.0864
# Train Log:Epoch: 30, Step [501/60000], TrainLoss: 2.1904
# Accuracy of the network on the test images: 10.51% & Test Loss: 2.368107650279999
# Train Log:Epoch: 31, Step [1/60000], TrainLoss: 2.1384
# Train Log:Epoch: 31, Step [501/60000], TrainLoss: 2.1281
# Accuracy of the network on the test images: 9.72% & Test Loss: 2.3827131581306458
# Train Log:Epoch: 32, Step [1/60000], TrainLoss: 2.0882
# Train Log:Epoch: 32, Step [501/60000], TrainLoss: 2.0812
# Accuracy of the network on the test images: 9.26% & Test Loss: 2.3941233468055727
# Train Log:Epoch: 33, Step [1/60000], TrainLoss: 2.1073
# Train Log:Epoch: 33, Step [501/60000], TrainLoss: 2.0998
# Accuracy of the network on the test images: 9.49% & Test Loss: 2.3894475412368776
# Train Log:Epoch: 34, Step [1/60000], TrainLoss: 2.1035
# Train Log:Epoch: 34, Step [501/60000], TrainLoss: 2.1223
# Accuracy of the network on the test images: 9.56% & Test Loss: 2.3958474135398866
# Train Log:Epoch: 35, Step [1/60000], TrainLoss: 2.1130
# Train Log:Epoch: 35, Step [501/60000], TrainLoss: 2.0804
# Accuracy of the network on the test images: 9.66% & Test Loss: 2.390751984119415
# Train Log:Epoch: 36, Step [1/60000], TrainLoss: 2.0389
# Train Log:Epoch: 36, Step [501/60000], TrainLoss: 2.0536
# Accuracy of the network on the test images: 9.35% & Test Loss: 2.4122251319885253
# Train Log:Epoch: 37, Step [1/60000], TrainLoss: 2.1134
# Train Log:Epoch: 37, Step [501/60000], TrainLoss: 2.0940
# Accuracy of the network on the test images: 10.13% & Test Loss: 2.4090352296829223
# Train Log:Epoch: 38, Step [1/60000], TrainLoss: 2.0550
# Train Log:Epoch: 38, Step [501/60000], TrainLoss: 2.0680
# Accuracy of the network on the test images: 11.03% & Test Loss: 2.3730492186546326
# Train Log:Epoch: 39, Step [1/60000], TrainLoss: 2.0196
# Train Log:Epoch: 39, Step [501/60000], TrainLoss: 2.1193
# Accuracy of the network on the test images: 9.57% & Test Loss: 2.4194317197799684
# Train Log:Epoch: 40, Step [1/60000], TrainLoss: 2.1078
# Train Log:Epoch: 40, Step [501/60000], TrainLoss: 2.1370
# Accuracy of the network on the test images: 9.21% & Test Loss: 2.4348708486557005
# Train Log:Epoch: 41, Step [1/60000], TrainLoss: 1.9624
# Train Log:Epoch: 41, Step [501/60000], TrainLoss: 2.0107
# Accuracy of the network on the test images: 9.54% & Test Loss: 2.4199627208709718
# Train Log:Epoch: 42, Step [1/60000], TrainLoss: 2.0260
# Train Log:Epoch: 42, Step [501/60000], TrainLoss: 2.0433
# Accuracy of the network on the test images: 10.61% & Test Loss: 2.413402831554413
# Train Log:Epoch: 43, Step [1/60000], TrainLoss: 2.0720
# Train Log:Epoch: 43, Step [501/60000], TrainLoss: 2.0337
# Accuracy of the network on the test images: 9.96% & Test Loss: 2.430561037063599
# Train Log:Epoch: 44, Step [1/60000], TrainLoss: 2.0398
# Train Log:Epoch: 44, Step [501/60000], TrainLoss: 2.0676
# Accuracy of the network on the test images: 10.19% & Test Loss: 2.4314888095855713
# Train Log:Epoch: 45, Step [1/60000], TrainLoss: 2.0594
# Train Log:Epoch: 45, Step [501/60000], TrainLoss: 2.0478
# Accuracy of the network on the test images: 11.4% & Test Loss: 2.4013293862342833
# Train Log:Epoch: 46, Step [1/60000], TrainLoss: 2.0356
# Train Log:Epoch: 46, Step [501/60000], TrainLoss: 1.9623
# Accuracy of the network on the test images: 10.22% & Test Loss: 2.4150201582908633
# Train Log:Epoch: 47, Step [1/60000], TrainLoss: 2.0132
# Train Log:Epoch: 47, Step [501/60000], TrainLoss: 1.9752
# Accuracy of the network on the test images: 11.11% & Test Loss: 2.397792763710022
# Train Log:Epoch: 48, Step [1/60000], TrainLoss: 2.0007
# Train Log:Epoch: 48, Step [501/60000], TrainLoss: 1.9736
# Accuracy of the network on the test images: 9.99% & Test Loss: 2.452180151939392
# Train Log:Epoch: 49, Step [1/60000], TrainLoss: 2.0530
# Train Log:Epoch: 49, Step [501/60000], TrainLoss: 2.0283
# Accuracy of the network on the test images: 10.54% & Test Loss: 2.4195680689811705
# Train Log:Epoch: 50, Step [1/60000], TrainLoss: 1.9487
# Train Log:Epoch: 50, Step [501/60000], TrainLoss: 2.0008
# Accuracy of the network on the test images: 8.68% & Test Loss: 2.475615816116333
# Train Log:Epoch: 51, Step [1/60000], TrainLoss: 1.8744
# Train Log:Epoch: 51, Step [501/60000], TrainLoss: 2.0061
# Accuracy of the network on the test images: 10.68% & Test Loss: 2.423304045200348
# Train Log:Epoch: 52, Step [1/60000], TrainLoss: 2.0403
# Train Log:Epoch: 52, Step [501/60000], TrainLoss: 1.9480
# Accuracy of the network on the test images: 10.26% & Test Loss: 2.4503310251235964
# Train Log:Epoch: 53, Step [1/60000], TrainLoss: 1.9593
# Train Log:Epoch: 53, Step [501/60000], TrainLoss: 2.0105
# Accuracy of the network on the test images: 9.47% & Test Loss: 2.495469541549683
# Train Log:Epoch: 54, Step [1/60000], TrainLoss: 1.8798
# Train Log:Epoch: 54, Step [501/60000], TrainLoss: 1.9645
# Accuracy of the network on the test images: 9.3% & Test Loss: 2.495648653507233
# Train Log:Epoch: 55, Step [1/60000], TrainLoss: 1.8880
# Train Log:Epoch: 55, Step [501/60000], TrainLoss: 2.1218
# Accuracy of the network on the test images: 11.21% & Test Loss: 2.444698657989502
# Train Log:Epoch: 56, Step [1/60000], TrainLoss: 1.8368
# Train Log:Epoch: 56, Step [501/60000], TrainLoss: 1.9181
# Accuracy of the network on the test images: 12.22% & Test Loss: 2.4218863320350645
# Train Log:Epoch: 57, Step [1/60000], TrainLoss: 1.9960
# Train Log:Epoch: 57, Step [501/60000], TrainLoss: 1.8666
# Accuracy of the network on the test images: 10.38% & Test Loss: 2.4777359485626222
# Train Log:Epoch: 58, Step [1/60000], TrainLoss: 1.9338
# Train Log:Epoch: 58, Step [501/60000], TrainLoss: 1.9540
# Accuracy of the network on the test images: 9.97% & Test Loss: 2.49208301782608
# Train Log:Epoch: 59, Step [1/60000], TrainLoss: 1.9561
# Train Log:Epoch: 59, Step [501/60000], TrainLoss: 1.9814
# Accuracy of the network on the test images: 9.37% & Test Loss: 2.499325816631317
# Train Log:Epoch: 60, Step [1/60000], TrainLoss: 1.8805
# Train Log:Epoch: 60, Step [501/60000], TrainLoss: 2.0107
# Accuracy of the network on the test images: 9.78% & Test Loss: 2.4884113907814025
# Train Log:Epoch: 61, Step [1/60000], TrainLoss: 1.9362
# Train Log:Epoch: 61, Step [501/60000], TrainLoss: 1.9241
# Accuracy of the network on the test images: 8.73% & Test Loss: 2.528059329986572
# Train Log:Epoch: 62, Step [1/60000], TrainLoss: 1.8692
# Train Log:Epoch: 62, Step [501/60000], TrainLoss: 1.8995
# Accuracy of the network on the test images: 9.45% & Test Loss: 2.51535227060318
# Train Log:Epoch: 63, Step [1/60000], TrainLoss: 1.8384
# Train Log:Epoch: 63, Step [501/60000], TrainLoss: 1.8041
# Accuracy of the network on the test images: 9.93% & Test Loss: 2.504249465465546
# Train Log:Epoch: 64, Step [1/60000], TrainLoss: 1.8510
# Train Log:Epoch: 64, Step [501/60000], TrainLoss: 1.8726
# Accuracy of the network on the test images: 9.66% & Test Loss: 2.5201226043701173
# Train Log:Epoch: 65, Step [1/60000], TrainLoss: 1.8726
# Train Log:Epoch: 65, Step [501/60000], TrainLoss: 1.8901
# Accuracy of the network on the test images: 10.24% & Test Loss: 2.494630689620972
# Train Log:Epoch: 66, Step [1/60000], TrainLoss: 1.9212
# Train Log:Epoch: 66, Step [501/60000], TrainLoss: 1.9717
# Accuracy of the network on the test images: 10.15% & Test Loss: 2.5108374738693238
# Train Log:Epoch: 67, Step [1/60000], TrainLoss: 1.7674
# Train Log:Epoch: 67, Step [501/60000], TrainLoss: 1.7606
# Accuracy of the network on the test images: 11.08% & Test Loss: 2.4868652701377867
# Train Log:Epoch: 68, Step [1/60000], TrainLoss: 1.8690
# Train Log:Epoch: 68, Step [501/60000], TrainLoss: 1.9710
# Accuracy of the network on the test images: 10.41% & Test Loss: 2.516500232219696
# Train Log:Epoch: 69, Step [1/60000], TrainLoss: 1.9065
# Train Log:Epoch: 69, Step [501/60000], TrainLoss: 1.9123
# Accuracy of the network on the test images: 10.64% & Test Loss: 2.5023948979377746
# Train Log:Epoch: 70, Step [1/60000], TrainLoss: 1.7650
# Train Log:Epoch: 70, Step [501/60000], TrainLoss: 1.9828
# Accuracy of the network on the test images: 10.1% & Test Loss: 2.5278179907798766
# Train Log:Epoch: 71, Step [1/60000], TrainLoss: 1.7751
# Train Log:Epoch: 71, Step [501/60000], TrainLoss: 1.9239
# Accuracy of the network on the test images: 10.35% & Test Loss: 2.5016690945625304
# Train Log:Epoch: 72, Step [1/60000], TrainLoss: 1.8128
# Train Log:Epoch: 72, Step [501/60000], TrainLoss: 1.9715
# Accuracy of the network on the test images: 9.44% & Test Loss: 2.5461654543876646
# Train Log:Epoch: 73, Step [1/60000], TrainLoss: 1.8375
# Train Log:Epoch: 73, Step [501/60000], TrainLoss: 1.8415
# Accuracy of the network on the test images: 10.43% & Test Loss: 2.540755527019501
# Train Log:Epoch: 74, Step [1/60000], TrainLoss: 1.7245
# Train Log:Epoch: 74, Step [501/60000], TrainLoss: 1.8644
# Accuracy of the network on the test images: 9.64% & Test Loss: 2.5442857432365416
# Train Log:Epoch: 75, Step [1/60000], TrainLoss: 1.7983
# Train Log:Epoch: 75, Step [501/60000], TrainLoss: 1.7862
# Accuracy of the network on the test images: 10.02% & Test Loss: 2.5703719520568846
# Train Log:Epoch: 76, Step [1/60000], TrainLoss: 1.8023
# Train Log:Epoch: 76, Step [501/60000], TrainLoss: 1.8001
# Accuracy of the network on the test images: 9.12% & Test Loss: 2.5900169825553894
# Train Log:Epoch: 77, Step [1/60000], TrainLoss: 1.7230
# Train Log:Epoch: 77, Step [501/60000], TrainLoss: 1.7515
# Accuracy of the network on the test images: 9.07% & Test Loss: 2.5952473950386046
# Train Log:Epoch: 78, Step [1/60000], TrainLoss: 1.7181
# Train Log:Epoch: 78, Step [501/60000], TrainLoss: 1.8372
# Accuracy of the network on the test images: 9.84% & Test Loss: 2.57635155916214
# Train Log:Epoch: 79, Step [1/60000], TrainLoss: 1.8418
# Train Log:Epoch: 79, Step [501/60000], TrainLoss: 1.8091
# Accuracy of the network on the test images: 10.3% & Test Loss: 2.5661221647262575
# Train Log:Epoch: 80, Step [1/60000], TrainLoss: 1.6590
# Train Log:Epoch: 80, Step [501/60000], TrainLoss: 1.7235
# Accuracy of the network on the test images: 10.18% & Test Loss: 2.5806406235694883
# Train Log:Epoch: 81, Step [1/60000], TrainLoss: 1.9032
# Train Log:Epoch: 81, Step [501/60000], TrainLoss: 1.7437
# Accuracy of the network on the test images: 9.83% & Test Loss: 2.582245011329651
# Train Log:Epoch: 82, Step [1/60000], TrainLoss: 1.7552
# Train Log:Epoch: 82, Step [501/60000], TrainLoss: 1.7608
# Accuracy of the network on the test images: 10.39% & Test Loss: 2.565825045108795
# Train Log:Epoch: 83, Step [1/60000], TrainLoss: 1.8102
# Train Log:Epoch: 83, Step [501/60000], TrainLoss: 1.7276
# Accuracy of the network on the test images: 10.15% & Test Loss: 2.5831872510910032
# Train Log:Epoch: 84, Step [1/60000], TrainLoss: 1.7283
# Train Log:Epoch: 84, Step [501/60000], TrainLoss: 1.7645
# Accuracy of the network on the test images: 10.81% & Test Loss: 2.5652193665504455
# Train Log:Epoch: 85, Step [1/60000], TrainLoss: 1.8891
# Train Log:Epoch: 85, Step [501/60000], TrainLoss: 1.8250
# Accuracy of the network on the test images: 8.57% & Test Loss: 2.6599815320968627
# Train Log:Epoch: 86, Step [1/60000], TrainLoss: 1.7152
# Train Log:Epoch: 86, Step [501/60000], TrainLoss: 1.7391
# Accuracy of the network on the test images: 9.83% & Test Loss: 2.6084947276115416
# Train Log:Epoch: 87, Step [1/60000], TrainLoss: 1.7005
# Train Log:Epoch: 87, Step [501/60000], TrainLoss: 1.7673
# Accuracy of the network on the test images: 9.31% & Test Loss: 2.6183656787872316
# Train Log:Epoch: 88, Step [1/60000], TrainLoss: 1.8199
# Train Log:Epoch: 88, Step [501/60000], TrainLoss: 1.7121
# Accuracy of the network on the test images: 9.71% & Test Loss: 2.6185829639434814
# Train Log:Epoch: 89, Step [1/60000], TrainLoss: 1.6808
# Train Log:Epoch: 89, Step [501/60000], TrainLoss: 1.8013
# Accuracy of the network on the test images: 10.17% & Test Loss: 2.606937186717987
# Train Log:Epoch: 90, Step [1/60000], TrainLoss: 1.7300
# Train Log:Epoch: 90, Step [501/60000], TrainLoss: 1.7850
# Accuracy of the network on the test images: 10.36% & Test Loss: 2.5902958369255065
# Train Log:Epoch: 91, Step [1/60000], TrainLoss: 1.7818
# Train Log:Epoch: 91, Step [501/60000], TrainLoss: 1.9337
# Accuracy of the network on the test images: 9.67% & Test Loss: 2.6312216305732727
# Train Log:Epoch: 92, Step [1/60000], TrainLoss: 1.7104
# Train Log:Epoch: 92, Step [501/60000], TrainLoss: 1.5983
# Accuracy of the network on the test images: 10.03% & Test Loss: 2.6359492349624634
# Train Log:Epoch: 93, Step [1/60000], TrainLoss: 1.6994
# Train Log:Epoch: 93, Step [501/60000], TrainLoss: 1.6374
# Accuracy of the network on the test images: 9.24% & Test Loss: 2.651467733383179
# Train Log:Epoch: 94, Step [1/60000], TrainLoss: 1.7450
# Train Log:Epoch: 94, Step [501/60000], TrainLoss: 1.6025
# Accuracy of the network on the test images: 9.4% & Test Loss: 2.6676262521743777
# Train Log:Epoch: 95, Step [1/60000], TrainLoss: 1.7270
# Train Log:Epoch: 95, Step [501/60000], TrainLoss: 1.6784
# Accuracy of the network on the test images: 9.29% & Test Loss: 2.6707422161102294
# Train Log:Epoch: 96, Step [1/60000], TrainLoss: 1.6419
# Train Log:Epoch: 96, Step [501/60000], TrainLoss: 1.6577
# Accuracy of the network on the test images: 9.78% & Test Loss: 2.655820550918579
# Train Log:Epoch: 97, Step [1/60000], TrainLoss: 1.6066
# Train Log:Epoch: 97, Step [501/60000], TrainLoss: 1.7096
# Accuracy of the network on the test images: 9.44% & Test Loss: 2.686105785369873
# Train Log:Epoch: 98, Step [1/60000], TrainLoss: 1.7161
# Train Log:Epoch: 98, Step [501/60000], TrainLoss: 1.7655
# Accuracy of the network on the test images: 9.34% & Test Loss: 2.6948857045173646
# Train Log:Epoch: 99, Step [1/60000], TrainLoss: 1.6545
# Train Log:Epoch: 99, Step [501/60000], TrainLoss: 1.7322
# Accuracy of the network on the test images: 9.66% & Test Loss: 2.657797338962555
# Train Log:Epoch: 100, Step [1/60000], TrainLoss: 1.7343
# Train Log:Epoch: 100, Step [501/60000], TrainLoss: 1.6604
# Accuracy of the network on the test images: 10.02% & Test Loss: 2.6647531533241273
# Train Log:Epoch: 101, Step [1/60000], TrainLoss: 1.5701
# Train Log:Epoch: 101, Step [501/60000], TrainLoss: 1.6756
# Accuracy of the network on the test images: 8.1% & Test Loss: 2.7289087986946106
# Train Log:Epoch: 102, Step [1/60000], TrainLoss: 1.6706
# Train Log:Epoch: 102, Step [501/60000], TrainLoss: 1.7001
# Accuracy of the network on the test images: 9.14% & Test Loss: 2.7252080965042116
# Train Log:Epoch: 103, Step [1/60000], TrainLoss: 1.5300
# Train Log:Epoch: 103, Step [501/60000], TrainLoss: 1.7632
# Accuracy of the network on the test images: 10.17% & Test Loss: 2.672349352836609
# Train Log:Epoch: 104, Step [1/60000], TrainLoss: 1.7139
# Train Log:Epoch: 104, Step [501/60000], TrainLoss: 1.6760
# Accuracy of the network on the test images: 9.73% & Test Loss: 2.686883764266968
# Train Log:Epoch: 105, Step [1/60000], TrainLoss: 1.6304
# Train Log:Epoch: 105, Step [501/60000], TrainLoss: 1.6372
# Accuracy of the network on the test images: 10.06% & Test Loss: 2.6726288557052613
# Train Log:Epoch: 106, Step [1/60000], TrainLoss: 1.6716
# Train Log:Epoch: 106, Step [501/60000], TrainLoss: 1.5219
# Accuracy of the network on the test images: 10.38% & Test Loss: 2.6801375222206114
# Train Log:Epoch: 107, Step [1/60000], TrainLoss: 1.6439
# Train Log:Epoch: 107, Step [501/60000], TrainLoss: 1.5667
# Accuracy of the network on the test images: 9.31% & Test Loss: 2.713508381843567
# Train Log:Epoch: 108, Step [1/60000], TrainLoss: 1.6430
# Train Log:Epoch: 108, Step [501/60000], TrainLoss: 1.6668
# Accuracy of the network on the test images: 9.88% & Test Loss: 2.692998244762421
# Train Log:Epoch: 109, Step [1/60000], TrainLoss: 1.6158
# Train Log:Epoch: 109, Step [501/60000], TrainLoss: 1.6182
# Accuracy of the network on the test images: 9.85% & Test Loss: 2.716017780303955
# Train Log:Epoch: 110, Step [1/60000], TrainLoss: 1.6254
# Train Log:Epoch: 110, Step [501/60000], TrainLoss: 1.6118
# Accuracy of the network on the test images: 9.47% & Test Loss: 2.722709400653839
# Train Log:Epoch: 111, Step [1/60000], TrainLoss: 1.5114
# Train Log:Epoch: 111, Step [501/60000], TrainLoss: 1.6286
# Accuracy of the network on the test images: 9.16% & Test Loss: 2.7619006705284117
# Train Log:Epoch: 112, Step [1/60000], TrainLoss: 1.5674
# Train Log:Epoch: 112, Step [501/60000], TrainLoss: 1.5779
# Accuracy of the network on the test images: 10.9% & Test Loss: 2.6718929529190065
# Train Log:Epoch: 113, Step [1/60000], TrainLoss: 1.5601
# Train Log:Epoch: 113, Step [501/60000], TrainLoss: 1.5308
# Accuracy of the network on the test images: 9.26% & Test Loss: 2.7433143067359924
# Train Log:Epoch: 114, Step [1/60000], TrainLoss: 1.4514
# Train Log:Epoch: 114, Step [501/60000], TrainLoss: 1.6194
# Accuracy of the network on the test images: 10.17% & Test Loss: 2.713519740104675
# Train Log:Epoch: 115, Step [1/60000], TrainLoss: 1.4709
# Train Log:Epoch: 115, Step [501/60000], TrainLoss: 1.6848
# Accuracy of the network on the test images: 9.59% & Test Loss: 2.742891707420349
# Train Log:Epoch: 116, Step [1/60000], TrainLoss: 1.4634
# Train Log:Epoch: 116, Step [501/60000], TrainLoss: 1.6672
# Accuracy of the network on the test images: 10.04% & Test Loss: 2.74486453294754
# Train Log:Epoch: 117, Step [1/60000], TrainLoss: 1.5318
# Train Log:Epoch: 117, Step [501/60000], TrainLoss: 1.6162
# Accuracy of the network on the test images: 9.22% & Test Loss: 2.7653913927078246
# Train Log:Epoch: 118, Step [1/60000], TrainLoss: 1.5655
# Train Log:Epoch: 118, Step [501/60000], TrainLoss: 1.5085
# Accuracy of the network on the test images: 9.63% & Test Loss: 2.7550902271270754
# Train Log:Epoch: 119, Step [1/60000], TrainLoss: 1.5557
# Train Log:Epoch: 119, Step [501/60000], TrainLoss: 1.5252
# Accuracy of the network on the test images: 9.25% & Test Loss: 2.77708505153656
# Train Log:Epoch: 120, Step [1/60000], TrainLoss: 1.5401
# Train Log:Epoch: 120, Step [501/60000], TrainLoss: 1.5201
# Accuracy of the network on the test images: 10.27% & Test Loss: 2.752916705608368
# Train Log:Epoch: 121, Step [1/60000], TrainLoss: 1.5156
# Train Log:Epoch: 121, Step [501/60000], TrainLoss: 1.4770
# Accuracy of the network on the test images: 9.33% & Test Loss: 2.7765931987762453
# Train Log:Epoch: 122, Step [1/60000], TrainLoss: 1.4547
# Train Log:Epoch: 122, Step [501/60000], TrainLoss: 1.5486
# Accuracy of the network on the test images: 9.73% & Test Loss: 2.756584811210632
# Train Log:Epoch: 123, Step [1/60000], TrainLoss: 1.5646
# Train Log:Epoch: 123, Step [501/60000], TrainLoss: 1.5484
# Accuracy of the network on the test images: 9.48% & Test Loss: 2.797088339328766
# Train Log:Epoch: 124, Step [1/60000], TrainLoss: 1.5478
# Train Log:Epoch: 124, Step [501/60000], TrainLoss: 1.6063
# Accuracy of the network on the test images: 9.75% & Test Loss: 2.78807816028595
# Train Log:Epoch: 125, Step [1/60000], TrainLoss: 1.5539
# Train Log:Epoch: 125, Step [501/60000], TrainLoss: 1.5700
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.7638229084014894
# Train Log:Epoch: 126, Step [1/60000], TrainLoss: 1.4674
# Train Log:Epoch: 126, Step [501/60000], TrainLoss: 1.4464
# Accuracy of the network on the test images: 9.19% & Test Loss: 2.8287329936027525
# Train Log:Epoch: 127, Step [1/60000], TrainLoss: 1.4851
# Train Log:Epoch: 127, Step [501/60000], TrainLoss: 1.5239
# Accuracy of the network on the test images: 10.55% & Test Loss: 2.781932942867279
# Train Log:Epoch: 128, Step [1/60000], TrainLoss: 1.4595
# Train Log:Epoch: 128, Step [501/60000], TrainLoss: 1.4691
# Accuracy of the network on the test images: 9.35% & Test Loss: 2.8235613536834716
# Train Log:Epoch: 129, Step [1/60000], TrainLoss: 1.5402
# Train Log:Epoch: 129, Step [501/60000], TrainLoss: 1.5316
# Accuracy of the network on the test images: 8.5% & Test Loss: 2.842068212032318
# Train Log:Epoch: 130, Step [1/60000], TrainLoss: 1.5004
# Train Log:Epoch: 130, Step [501/60000], TrainLoss: 1.4212
# Accuracy of the network on the test images: 8.47% & Test Loss: 2.8843157744407653
# Train Log:Epoch: 131, Step [1/60000], TrainLoss: 1.4438
# Train Log:Epoch: 131, Step [501/60000], TrainLoss: 1.6253
# Accuracy of the network on the test images: 10.14% & Test Loss: 2.844930214881897
# Train Log:Epoch: 132, Step [1/60000], TrainLoss: 1.4808
# Train Log:Epoch: 132, Step [501/60000], TrainLoss: 1.3688
# Accuracy of the network on the test images: 9.53% & Test Loss: 2.817148449420929
# Train Log:Epoch: 133, Step [1/60000], TrainLoss: 1.3329
# Train Log:Epoch: 133, Step [501/60000], TrainLoss: 1.4392
# Accuracy of the network on the test images: 9.16% & Test Loss: 2.8580065321922303
# Train Log:Epoch: 134, Step [1/60000], TrainLoss: 1.4289
# Train Log:Epoch: 134, Step [501/60000], TrainLoss: 1.5464
# Accuracy of the network on the test images: 9.54% & Test Loss: 2.8352883291244506
# Train Log:Epoch: 135, Step [1/60000], TrainLoss: 1.3810
# Train Log:Epoch: 135, Step [501/60000], TrainLoss: 1.5239
# Accuracy of the network on the test images: 9.14% & Test Loss: 2.8820347905159
# Train Log:Epoch: 136, Step [1/60000], TrainLoss: 1.2893
# Train Log:Epoch: 136, Step [501/60000], TrainLoss: 1.4343
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.8498230624198913
# Train Log:Epoch: 137, Step [1/60000], TrainLoss: 1.2473
# Train Log:Epoch: 137, Step [501/60000], TrainLoss: 1.4325
# Accuracy of the network on the test images: 8.98% & Test Loss: 2.8863593220710753
# Train Log:Epoch: 138, Step [1/60000], TrainLoss: 1.4635
# Train Log:Epoch: 138, Step [501/60000], TrainLoss: 1.3419
# Accuracy of the network on the test images: 8.88% & Test Loss: 2.8961065793037415
# Train Log:Epoch: 139, Step [1/60000], TrainLoss: 1.5280
# Train Log:Epoch: 139, Step [501/60000], TrainLoss: 1.3891
# Accuracy of the network on the test images: 9.78% & Test Loss: 2.827820761203766
# Train Log:Epoch: 140, Step [1/60000], TrainLoss: 1.6245
# Train Log:Epoch: 140, Step [501/60000], TrainLoss: 1.3254
# Accuracy of the network on the test images: 8.95% & Test Loss: 2.9028759002685547
# Train Log:Epoch: 141, Step [1/60000], TrainLoss: 1.4390
# Train Log:Epoch: 141, Step [501/60000], TrainLoss: 1.5387
# Accuracy of the network on the test images: 10.46% & Test Loss: 2.851006278991699
# Train Log:Epoch: 142, Step [1/60000], TrainLoss: 1.3450
# Train Log:Epoch: 142, Step [501/60000], TrainLoss: 1.4595
# Accuracy of the network on the test images: 9.74% & Test Loss: 2.871560800075531
# Train Log:Epoch: 143, Step [1/60000], TrainLoss: 1.4913
# Train Log:Epoch: 143, Step [501/60000], TrainLoss: 1.4152
# Accuracy of the network on the test images: 10.14% & Test Loss: 2.8521319103240965
# Train Log:Epoch: 144, Step [1/60000], TrainLoss: 1.4094
# Train Log:Epoch: 144, Step [501/60000], TrainLoss: 1.4245
# Accuracy of the network on the test images: 9.75% & Test Loss: 2.8989841771125793
# Train Log:Epoch: 145, Step [1/60000], TrainLoss: 1.2725
# Train Log:Epoch: 145, Step [501/60000], TrainLoss: 1.3789
# Accuracy of the network on the test images: 9.42% & Test Loss: 2.8890952110290526
# Train Log:Epoch: 146, Step [1/60000], TrainLoss: 1.2805
# Train Log:Epoch: 146, Step [501/60000], TrainLoss: 1.2721
# Accuracy of the network on the test images: 9.69% & Test Loss: 2.9031800270080566
# Train Log:Epoch: 147, Step [1/60000], TrainLoss: 1.3745
# Train Log:Epoch: 147, Step [501/60000], TrainLoss: 1.4147
# Accuracy of the network on the test images: 9.35% & Test Loss: 2.9083069276809694
# Train Log:Epoch: 148, Step [1/60000], TrainLoss: 1.2864
# Train Log:Epoch: 148, Step [501/60000], TrainLoss: 1.5300
# Accuracy of the network on the test images: 9.52% & Test Loss: 2.936175801753998
# Train Log:Epoch: 149, Step [1/60000], TrainLoss: 1.4542
# Train Log:Epoch: 149, Step [501/60000], TrainLoss: 1.4679
# Accuracy of the network on the test images: 9.78% & Test Loss: 2.9133589577674868
# Train Log:Epoch: 150, Step [1/60000], TrainLoss: 1.3680
# Train Log:Epoch: 150, Step [501/60000], TrainLoss: 1.4469
# Accuracy of the network on the test images: 10.43% & Test Loss: 2.880317611694336
# Train Log:Epoch: 151, Step [1/60000], TrainLoss: 1.4261
# Train Log:Epoch: 151, Step [501/60000], TrainLoss: 1.4496
# Accuracy of the network on the test images: 9.16% & Test Loss: 2.9389070773124697
# Train Log:Epoch: 152, Step [1/60000], TrainLoss: 1.3151
# Train Log:Epoch: 152, Step [501/60000], TrainLoss: 1.4550
# Accuracy of the network on the test images: 9.34% & Test Loss: 2.956279904842377
# Train Log:Epoch: 153, Step [1/60000], TrainLoss: 1.3379
# Train Log:Epoch: 153, Step [501/60000], TrainLoss: 1.4623
# Accuracy of the network on the test images: 9.58% & Test Loss: 2.9536012697219847
# Train Log:Epoch: 154, Step [1/60000], TrainLoss: 1.5126
# Train Log:Epoch: 154, Step [501/60000], TrainLoss: 1.4152
# Accuracy of the network on the test images: 11.09% & Test Loss: 2.882484965324402
# Train Log:Epoch: 155, Step [1/60000], TrainLoss: 1.3549
# Train Log:Epoch: 155, Step [501/60000], TrainLoss: 1.3317
# Accuracy of the network on the test images: 9.05% & Test Loss: 2.9772887325286863
# Train Log:Epoch: 156, Step [1/60000], TrainLoss: 1.3925
# Train Log:Epoch: 156, Step [501/60000], TrainLoss: 1.4282
# Accuracy of the network on the test images: 10.02% & Test Loss: 2.93118141412735
# Train Log:Epoch: 157, Step [1/60000], TrainLoss: 1.2368
# Train Log:Epoch: 157, Step [501/60000], TrainLoss: 1.3682
# Accuracy of the network on the test images: 9.87% & Test Loss: 2.9376124143600464
# Train Log:Epoch: 158, Step [1/60000], TrainLoss: 1.3039
# Train Log:Epoch: 158, Step [501/60000], TrainLoss: 1.2946
# Accuracy of the network on the test images: 9.74% & Test Loss: 2.9668565368652344
# Train Log:Epoch: 159, Step [1/60000], TrainLoss: 1.4075
# Train Log:Epoch: 159, Step [501/60000], TrainLoss: 1.4646
# Accuracy of the network on the test images: 11.17% & Test Loss: 2.9181463050842287
# Train Log:Epoch: 160, Step [1/60000], TrainLoss: 1.3643
# Train Log:Epoch: 160, Step [501/60000], TrainLoss: 1.2976
# Accuracy of the network on the test images: 10.33% & Test Loss: 2.94252858877182
# Train Log:Epoch: 161, Step [1/60000], TrainLoss: 1.4557
# Train Log:Epoch: 161, Step [501/60000], TrainLoss: 1.6078
# Accuracy of the network on the test images: 9.62% & Test Loss: 2.9988181018829345
# Train Log:Epoch: 162, Step [1/60000], TrainLoss: 1.3806
# Train Log:Epoch: 162, Step [501/60000], TrainLoss: 1.3849
# Accuracy of the network on the test images: 9.36% & Test Loss: 2.9857239603996275
# Train Log:Epoch: 163, Step [1/60000], TrainLoss: 1.3443
# Train Log:Epoch: 163, Step [501/60000], TrainLoss: 1.3450
# Accuracy of the network on the test images: 9.83% & Test Loss: 2.973924036026001
# Train Log:Epoch: 164, Step [1/60000], TrainLoss: 1.2575
# Train Log:Epoch: 164, Step [501/60000], TrainLoss: 1.2306
# Accuracy of the network on the test images: 9.42% & Test Loss: 2.9839917993545533
# Train Log:Epoch: 165, Step [1/60000], TrainLoss: 1.1509
# Train Log:Epoch: 165, Step [501/60000], TrainLoss: 1.3642
# Accuracy of the network on the test images: 10.11% & Test Loss: 2.9709498691558838
# Train Log:Epoch: 166, Step [1/60000], TrainLoss: 1.2116
# Train Log:Epoch: 166, Step [501/60000], TrainLoss: 1.3202
# Accuracy of the network on the test images: 9.56% & Test Loss: 3.000069432258606
# Train Log:Epoch: 167, Step [1/60000], TrainLoss: 1.3358
# Train Log:Epoch: 167, Step [501/60000], TrainLoss: 1.2611
# Accuracy of the network on the test images: 9.04% & Test Loss: 3.0623949813842772
# Train Log:Epoch: 168, Step [1/60000], TrainLoss: 1.2384
# Train Log:Epoch: 168, Step [501/60000], TrainLoss: 1.0702
# Accuracy of the network on the test images: 9.36% & Test Loss: 3.0170746064186096
# Train Log:Epoch: 169, Step [1/60000], TrainLoss: 1.1993
# Train Log:Epoch: 169, Step [501/60000], TrainLoss: 1.3833
# Accuracy of the network on the test images: 9.44% & Test Loss: 3.0271955037117007
# Train Log:Epoch: 170, Step [1/60000], TrainLoss: 1.2450
# Train Log:Epoch: 170, Step [501/60000], TrainLoss: 1.3766
# Accuracy of the network on the test images: 10.59% & Test Loss: 2.977134790420532
# Train Log:Epoch: 171, Step [1/60000], TrainLoss: 1.1845
# Train Log:Epoch: 171, Step [501/60000], TrainLoss: 1.3556
# Accuracy of the network on the test images: 9.69% & Test Loss: 3.0185024309158326
# Train Log:Epoch: 172, Step [1/60000], TrainLoss: 1.2853
# Train Log:Epoch: 172, Step [501/60000], TrainLoss: 1.2006
# Accuracy of the network on the test images: 9.88% & Test Loss: 3.0393850779533387
# Train Log:Epoch: 173, Step [1/60000], TrainLoss: 1.2300
# Train Log:Epoch: 173, Step [501/60000], TrainLoss: 1.2672
# Accuracy of the network on the test images: 8.88% & Test Loss: 3.0855967807769775
# Train Log:Epoch: 174, Step [1/60000], TrainLoss: 1.1959
# Train Log:Epoch: 174, Step [501/60000], TrainLoss: 1.2906
# Accuracy of the network on the test images: 9.73% & Test Loss: 3.025448181629181
# Train Log:Epoch: 175, Step [1/60000], TrainLoss: 1.2265
# Train Log:Epoch: 175, Step [501/60000], TrainLoss: 1.4134
# Accuracy of the network on the test images: 9.58% & Test Loss: 3.0696976494789125
# Train Log:Epoch: 176, Step [1/60000], TrainLoss: 1.1430
# Train Log:Epoch: 176, Step [501/60000], TrainLoss: 1.1560
# Accuracy of the network on the test images: 9.39% & Test Loss: 3.075278356075287
# Train Log:Epoch: 177, Step [1/60000], TrainLoss: 1.1509
# Train Log:Epoch: 177, Step [501/60000], TrainLoss: 1.3040
# Accuracy of the network on the test images: 9.89% & Test Loss: 3.047484622001648
# Train Log:Epoch: 178, Step [1/60000], TrainLoss: 1.2420
# Train Log:Epoch: 178, Step [501/60000], TrainLoss: 1.2201
# Accuracy of the network on the test images: 9.08% & Test Loss: 3.098924798965454
# Train Log:Epoch: 179, Step [1/60000], TrainLoss: 1.2351
# Train Log:Epoch: 179, Step [501/60000], TrainLoss: 1.3170
# Accuracy of the network on the test images: 10.28% & Test Loss: 3.0827667021751406
# Train Log:Epoch: 180, Step [1/60000], TrainLoss: 1.2459
# Train Log:Epoch: 180, Step [501/60000], TrainLoss: 1.3595
# Accuracy of the network on the test images: 10.33% & Test Loss: 3.060088109970093
# Train Log:Epoch: 181, Step [1/60000], TrainLoss: 1.0944
# Train Log:Epoch: 181, Step [501/60000], TrainLoss: 1.1910
# Accuracy of the network on the test images: 10.1% & Test Loss: 3.0478157424926757
# Train Log:Epoch: 182, Step [1/60000], TrainLoss: 1.2645
# Train Log:Epoch: 182, Step [501/60000], TrainLoss: 1.2462
# Accuracy of the network on the test images: 10.06% & Test Loss: 3.0425334358215332
# Train Log:Epoch: 183, Step [1/60000], TrainLoss: 1.0817
# Train Log:Epoch: 183, Step [501/60000], TrainLoss: 1.2755
# Accuracy of the network on the test images: 9.78% & Test Loss: 3.101603443622589
# Train Log:Epoch: 184, Step [1/60000], TrainLoss: 1.2221
# Train Log:Epoch: 184, Step [501/60000], TrainLoss: 1.2354
# Accuracy of the network on the test images: 9.95% & Test Loss: 3.086962616443634
# Train Log:Epoch: 185, Step [1/60000], TrainLoss: 1.2974
# Train Log:Epoch: 185, Step [501/60000], TrainLoss: 1.3394
# Accuracy of the network on the test images: 9.1% & Test Loss: 3.1523609447479246
# Train Log:Epoch: 186, Step [1/60000], TrainLoss: 1.2014
# Train Log:Epoch: 186, Step [501/60000], TrainLoss: 1.2111
# Accuracy of the network on the test images: 8.94% & Test Loss: 3.1451694536209107
# Train Log:Epoch: 187, Step [1/60000], TrainLoss: 1.0897
# Train Log:Epoch: 187, Step [501/60000], TrainLoss: 1.2633
# Accuracy of the network on the test images: 10.05% & Test Loss: 3.1042347383499145
# Train Log:Epoch: 188, Step [1/60000], TrainLoss: 1.2784
# Train Log:Epoch: 188, Step [501/60000], TrainLoss: 1.1085
# Accuracy of the network on the test images: 10.12% & Test Loss: 3.1322676134109497
# Train Log:Epoch: 189, Step [1/60000], TrainLoss: 1.2076
# Train Log:Epoch: 189, Step [501/60000], TrainLoss: 1.2713
# Accuracy of the network on the test images: 10.37% & Test Loss: 3.0709707856178285
# Train Log:Epoch: 190, Step [1/60000], TrainLoss: 1.2701
# Train Log:Epoch: 190, Step [501/60000], TrainLoss: 1.1527
# Accuracy of the network on the test images: 9.57% & Test Loss: 3.160048816204071
# Train Log:Epoch: 191, Step [1/60000], TrainLoss: 1.1073
# Train Log:Epoch: 191, Step [501/60000], TrainLoss: 1.1504
# Accuracy of the network on the test images: 10.09% & Test Loss: 3.0954328203201293
# Train Log:Epoch: 192, Step [1/60000], TrainLoss: 1.2607
# Train Log:Epoch: 192, Step [501/60000], TrainLoss: 1.3146
# Accuracy of the network on the test images: 9.54% & Test Loss: 3.157064480781555
# Train Log:Epoch: 193, Step [1/60000], TrainLoss: 1.2779
# Train Log:Epoch: 193, Step [501/60000], TrainLoss: 1.2388
# Accuracy of the network on the test images: 9.24% & Test Loss: 3.1778074741363525
# Train Log:Epoch: 194, Step [1/60000], TrainLoss: 1.2095
# Train Log:Epoch: 194, Step [501/60000], TrainLoss: 1.2778
# Accuracy of the network on the test images: 9.81% & Test Loss: 3.169055533409119
# Train Log:Epoch: 195, Step [1/60000], TrainLoss: 1.2555
# Train Log:Epoch: 195, Step [501/60000], TrainLoss: 1.1062
# Accuracy of the network on the test images: 10.35% & Test Loss: 3.0993649101257326
# Train Log:Epoch: 196, Step [1/60000], TrainLoss: 1.0568
# Train Log:Epoch: 196, Step [501/60000], TrainLoss: 1.2230
# Accuracy of the network on the test images: 10.58% & Test Loss: 3.1006797218322752
# Train Log:Epoch: 197, Step [1/60000], TrainLoss: 1.1136
# Train Log:Epoch: 197, Step [501/60000], TrainLoss: 1.3542
# Accuracy of the network on the test images: 10.09% & Test Loss: 3.133870279788971
# Train Log:Epoch: 198, Step [1/60000], TrainLoss: 1.1143
# Train Log:Epoch: 198, Step [501/60000], TrainLoss: 1.1592
# Accuracy of the network on the test images: 9.72% & Test Loss: 3.201833198070526
# Train Log:Epoch: 199, Step [1/60000], TrainLoss: 1.1512
# Train Log:Epoch: 199, Step [501/60000], TrainLoss: 1.2023
# Accuracy of the network on the test images: 9.39% & Test Loss: 3.2142147850990295
# Train Log:Epoch: 200, Step [1/60000], TrainLoss: 1.1077
# Train Log:Epoch: 200, Step [501/60000], TrainLoss: 1.1634
# Accuracy of the network on the test images: 9.96% & Test Loss: 3.164549722671509
# Train Log:Epoch: 201, Step [1/60000], TrainLoss: 1.1087
# Train Log:Epoch: 201, Step [501/60000], TrainLoss: 1.2173
# Accuracy of the network on the test images: 9.95% & Test Loss: 3.1984557700157166
# Train Log:Epoch: 202, Step [1/60000], TrainLoss: 1.0863
# Train Log:Epoch: 202, Step [501/60000], TrainLoss: 1.2038
# Accuracy of the network on the test images: 10.15% & Test Loss: 3.200867736339569
# Train Log:Epoch: 203, Step [1/60000], TrainLoss: 1.0862
# Train Log:Epoch: 203, Step [501/60000], TrainLoss: 1.0772
# Accuracy of the network on the test images: 11.62% & Test Loss: 3.2023184752464293
# Train Log:Epoch: 204, Step [1/60000], TrainLoss: 1.2230
# Train Log:Epoch: 204, Step [501/60000], TrainLoss: 1.1832
# Accuracy of the network on the test images: 9.54% & Test Loss: 3.2281946301460267
# Train Log:Epoch: 205, Step [1/60000], TrainLoss: 1.0382
# Train Log:Epoch: 205, Step [501/60000], TrainLoss: 1.1948
# Accuracy of the network on the test images: 9.41% & Test Loss: 3.2471131539344786
# Train Log:Epoch: 206, Step [1/60000], TrainLoss: 0.9332
# Train Log:Epoch: 206, Step [501/60000], TrainLoss: 1.1750
# Accuracy of the network on the test images: 9.61% & Test Loss: 3.2314734077453613
# Train Log:Epoch: 207, Step [1/60000], TrainLoss: 1.0406
# Train Log:Epoch: 207, Step [501/60000], TrainLoss: 1.1282
# Accuracy of the network on the test images: 10.05% & Test Loss: 3.2057053995132447
# Train Log:Epoch: 208, Step [1/60000], TrainLoss: 1.0828
# Train Log:Epoch: 208, Step [501/60000], TrainLoss: 1.1195
# Accuracy of the network on the test images: 10.56% & Test Loss: 3.191535451412201
# Train Log:Epoch: 209, Step [1/60000], TrainLoss: 1.1261
# Train Log:Epoch: 209, Step [501/60000], TrainLoss: 1.1968
# Accuracy of the network on the test images: 9.49% & Test Loss: 3.2700639081001284
# Train Log:Epoch: 210, Step [1/60000], TrainLoss: 1.0042
# Train Log:Epoch: 210, Step [501/60000], TrainLoss: 1.0849
# Accuracy of the network on the test images: 9.8% & Test Loss: 3.263536014556885
# Train Log:Epoch: 211, Step [1/60000], TrainLoss: 1.1414
# Train Log:Epoch: 211, Step [501/60000], TrainLoss: 1.2292
# Accuracy of the network on the test images: 8.77% & Test Loss: 3.301987316608429
# Train Log:Epoch: 212, Step [1/60000], TrainLoss: 1.4077
# Train Log:Epoch: 212, Step [501/60000], TrainLoss: 1.0167
# Accuracy of the network on the test images: 9.83% & Test Loss: 3.3099150538444517
# Train Log:Epoch: 213, Step [1/60000], TrainLoss: 1.1656
# Train Log:Epoch: 213, Step [501/60000], TrainLoss: 1.0084
# Accuracy of the network on the test images: 10.56% & Test Loss: 3.2326998138427734
# Train Log:Epoch: 214, Step [1/60000], TrainLoss: 1.1080
# Train Log:Epoch: 214, Step [501/60000], TrainLoss: 1.0601
# Accuracy of the network on the test images: 9.88% & Test Loss: 3.2708983325958254
# Train Log:Epoch: 215, Step [1/60000], TrainLoss: 1.1027
# Train Log:Epoch: 215, Step [501/60000], TrainLoss: 1.1450
# Accuracy of the network on the test images: 8.73% & Test Loss: 3.34746958732605
# Train Log:Epoch: 216, Step [1/60000], TrainLoss: 1.1145
# Train Log:Epoch: 216, Step [501/60000], TrainLoss: 1.1851
# Accuracy of the network on the test images: 9.86% & Test Loss: 3.2757795333862303
# Train Log:Epoch: 217, Step [1/60000], TrainLoss: 1.0057
# Train Log:Epoch: 217, Step [501/60000], TrainLoss: 1.1505
# Accuracy of the network on the test images: 9.44% & Test Loss: 3.310764355659485
# Train Log:Epoch: 218, Step [1/60000], TrainLoss: 1.1357
# Train Log:Epoch: 218, Step [501/60000], TrainLoss: 1.1543
# Accuracy of the network on the test images: 9.53% & Test Loss: 3.320271906852722
# Train Log:Epoch: 219, Step [1/60000], TrainLoss: 0.9986
# Train Log:Epoch: 219, Step [501/60000], TrainLoss: 1.2058
# Accuracy of the network on the test images: 9.16% & Test Loss: 3.3420492720603945
# Train Log:Epoch: 220, Step [1/60000], TrainLoss: 1.0572
# Train Log:Epoch: 220, Step [501/60000], TrainLoss: 1.2380
# Accuracy of the network on the test images: 10.12% & Test Loss: 3.2768947076797486
# Train Log:Epoch: 221, Step [1/60000], TrainLoss: 0.9635
# Train Log:Epoch: 221, Step [501/60000], TrainLoss: 1.1657
# Accuracy of the network on the test images: 9.17% & Test Loss: 3.351750085353851
# Train Log:Epoch: 222, Step [1/60000], TrainLoss: 1.2743
# Train Log:Epoch: 222, Step [501/60000], TrainLoss: 1.2420
# Accuracy of the network on the test images: 10.28% & Test Loss: 3.3299831461906435
# Train Log:Epoch: 223, Step [1/60000], TrainLoss: 1.1333
# Train Log:Epoch: 223, Step [501/60000], TrainLoss: 1.0409
# Accuracy of the network on the test images: 9.83% & Test Loss: 3.3248740005493165
# Train Log:Epoch: 224, Step [1/60000], TrainLoss: 0.9318
# Train Log:Epoch: 224, Step [501/60000], TrainLoss: 1.0886
# Accuracy of the network on the test images: 10.34% & Test Loss: 3.322949810028076
# Train Log:Epoch: 225, Step [1/60000], TrainLoss: 1.0934
# Train Log:Epoch: 225, Step [501/60000], TrainLoss: 1.1139
# Accuracy of the network on the test images: 10.03% & Test Loss: 3.35965918302536
# Train Log:Epoch: 226, Step [1/60000], TrainLoss: 0.8993
# Train Log:Epoch: 226, Step [501/60000], TrainLoss: 1.0020
# Accuracy of the network on the test images: 9.87% & Test Loss: 3.3551270818710326
# Train Log:Epoch: 227, Step [1/60000], TrainLoss: 1.0406
# Train Log:Epoch: 227, Step [501/60000], TrainLoss: 1.0858
# Accuracy of the network on the test images: 9.67% & Test Loss: 3.358759255409241
# Train Log:Epoch: 228, Step [1/60000], TrainLoss: 0.9714
# Train Log:Epoch: 228, Step [501/60000], TrainLoss: 1.1908
# Accuracy of the network on the test images: 10.73% & Test Loss: 3.338977851867676
# Train Log:Epoch: 229, Step [1/60000], TrainLoss: 1.0118
# Train Log:Epoch: 229, Step [501/60000], TrainLoss: 1.1935
# Accuracy of the network on the test images: 10.27% & Test Loss: 3.34543128490448
# Train Log:Epoch: 230, Step [1/60000], TrainLoss: 1.0439
# Train Log:Epoch: 230, Step [501/60000], TrainLoss: 1.1026
# Accuracy of the network on the test images: 10.31% & Test Loss: 3.357745060920715
# Train Log:Epoch: 231, Step [1/60000], TrainLoss: 1.0605
# Train Log:Epoch: 231, Step [501/60000], TrainLoss: 1.0296
# Accuracy of the network on the test images: 9.77% & Test Loss: 3.3843210458755495
# Train Log:Epoch: 232, Step [1/60000], TrainLoss: 1.0879
# Train Log:Epoch: 232, Step [501/60000], TrainLoss: 1.0002
# Accuracy of the network on the test images: 9.48% & Test Loss: 3.407587504386902
# Train Log:Epoch: 233, Step [1/60000], TrainLoss: 1.0547
# Train Log:Epoch: 233, Step [501/60000], TrainLoss: 1.1532
# Accuracy of the network on the test images: 9.95% & Test Loss: 3.398923408985138
# Train Log:Epoch: 234, Step [1/60000], TrainLoss: 1.3131
# Train Log:Epoch: 234, Step [501/60000], TrainLoss: 0.9812
# Accuracy of the network on the test images: 10.27% & Test Loss: 3.3577941846847534
# Train Log:Epoch: 235, Step [1/60000], TrainLoss: 0.8938
# Train Log:Epoch: 235, Step [501/60000], TrainLoss: 1.1703
# Accuracy of the network on the test images: 10.69% & Test Loss: 3.334703063964844
# Train Log:Epoch: 236, Step [1/60000], TrainLoss: 0.9555
# Train Log:Epoch: 236, Step [501/60000], TrainLoss: 1.0735
# Accuracy of the network on the test images: 9.24% & Test Loss: 3.4524957299232484
# Train Log:Epoch: 237, Step [1/60000], TrainLoss: 0.9916
# Train Log:Epoch: 237, Step [501/60000], TrainLoss: 1.1058
# Accuracy of the network on the test images: 10.93% & Test Loss: 3.3471125173568725
# Train Log:Epoch: 238, Step [1/60000], TrainLoss: 1.1339
# Train Log:Epoch: 238, Step [501/60000], TrainLoss: 0.9722
# Accuracy of the network on the test images: 10.6% & Test Loss: 3.3328573155403136
# Train Log:Epoch: 239, Step [1/60000], TrainLoss: 1.0156
# Train Log:Epoch: 239, Step [501/60000], TrainLoss: 0.8951
# Accuracy of the network on the test images: 9.77% & Test Loss: 3.4207287335395815
# Train Log:Epoch: 240, Step [1/60000], TrainLoss: 1.0855
# Train Log:Epoch: 240, Step [501/60000], TrainLoss: 0.9208
# Accuracy of the network on the test images: 9.61% & Test Loss: 3.4319538354873655
# Train Log:Epoch: 241, Step [1/60000], TrainLoss: 0.8690
# Train Log:Epoch: 241, Step [501/60000], TrainLoss: 0.9913
# Accuracy of the network on the test images: 10.76% & Test Loss: 3.379618277549744
# Train Log:Epoch: 242, Step [1/60000], TrainLoss: 1.0466
# Train Log:Epoch: 242, Step [501/60000], TrainLoss: 0.9758
# Accuracy of the network on the test images: 9.85% & Test Loss: 3.4313340902328493
# Train Log:Epoch: 243, Step [1/60000], TrainLoss: 1.0473
# Train Log:Epoch: 243, Step [501/60000], TrainLoss: 0.9768
# Accuracy of the network on the test images: 9.72% & Test Loss: 3.4551644277572633
# Train Log:Epoch: 244, Step [1/60000], TrainLoss: 1.0834
# Train Log:Epoch: 244, Step [501/60000], TrainLoss: 1.0695
# Accuracy of the network on the test images: 9.87% & Test Loss: 3.4538447284698486
# Train Log:Epoch: 245, Step [1/60000], TrainLoss: 0.8823
# Train Log:Epoch: 245, Step [501/60000], TrainLoss: 1.1317
# Accuracy of the network on the test images: 10.1% & Test Loss: 3.4115890049934388
# Train Log:Epoch: 246, Step [1/60000], TrainLoss: 0.8316
# Train Log:Epoch: 246, Step [501/60000], TrainLoss: 1.0728
# ...
# Train Log:Epoch: 945, Step [501/60000], TrainLoss: 0.0848
# Accuracy of the network on the test images: 10.48% & Test Loss: 9.909981107711792
# Train Log:Epoch: 946, Step [1/60000], TrainLoss: 0.0568
# Train Log:Epoch: 946, Step [501/60000], TrainLoss: 0.0940
# Accuracy of the network on the test images: 9.54% & Test Loss: 10.075148329734802
# Train Log:Epoch: 947, Step [1/60000], TrainLoss: 0.0721
# Train Log:Epoch: 947, Step [501/60000], TrainLoss: 0.0722
# Accuracy of the network on the test images: 10.07% & Test Loss: 9.958715324401856
# Train Log:Epoch: 948, Step [1/60000], TrainLoss: 0.0533
# Train Log:Epoch: 948, Step [501/60000], TrainLoss: 0.0793
# Accuracy of the network on the test images: 10.32% & Test Loss: 10.002410068511963
# Train Log:Epoch: 949, Step [1/60000], TrainLoss: 0.0699
# Train Log:Epoch: 949, Step [501/60000], TrainLoss: 0.0429
# Accuracy of the network on the test images: 10.26% & Test Loss: 9.965519275665283
# Train Log:Epoch: 950, Step [1/60000], TrainLoss: 0.0721
# Train Log:Epoch: 950, Step [501/60000], TrainLoss: 0.1085
# Accuracy of the network on the test images: 9.53% & Test Loss: 10.088572988510132
# Train Log:Epoch: 951, Step [1/60000], TrainLoss: 0.0592
# Train Log:Epoch: 951, Step [501/60000], TrainLoss: 0.0954
# Accuracy of the network on the test images: 9.88% & Test Loss: 10.044147901535034
# Train Log:Epoch: 952, Step [1/60000], TrainLoss: 0.0737
# Train Log:Epoch: 952, Step [501/60000], TrainLoss: 0.0739
# Accuracy of the network on the test images: 10.2% & Test Loss: 10.038572039604187
# Train Log:Epoch: 953, Step [1/60000], TrainLoss: 0.0760
# Train Log:Epoch: 953, Step [501/60000], TrainLoss: 0.1585
# Accuracy of the network on the test images: 9.85% & Test Loss: 10.065425906181336
# Train Log:Epoch: 954, Step [1/60000], TrainLoss: 0.0965
# Train Log:Epoch: 954, Step [501/60000], TrainLoss: 0.0997
# Accuracy of the network on the test images: 10.05% & Test Loss: 10.101673831939697
# Train Log:Epoch: 955, Step [1/60000], TrainLoss: 0.0347
# Train Log:Epoch: 955, Step [501/60000], TrainLoss: 0.0962
# Accuracy of the network on the test images: 10.05% & Test Loss: 10.093073139190674
# Train Log:Epoch: 956, Step [1/60000], TrainLoss: 0.1131
# Train Log:Epoch: 956, Step [501/60000], TrainLoss: 0.1350
# Accuracy of the network on the test images: 9.58% & Test Loss: 10.136761755943299
# Train Log:Epoch: 957, Step [1/60000], TrainLoss: 0.0751
# Train Log:Epoch: 957, Step [501/60000], TrainLoss: 0.0828
# Accuracy of the network on the test images: 10.36% & Test Loss: 10.056730971336364
# Train Log:Epoch: 958, Step [1/60000], TrainLoss: 0.0890
# Train Log:Epoch: 958, Step [501/60000], TrainLoss: 0.0751
# Accuracy of the network on the test images: 10.54% & Test Loss: 10.04073473930359
# Train Log:Epoch: 959, Step [1/60000], TrainLoss: 0.0836
# Train Log:Epoch: 959, Step [501/60000], TrainLoss: 0.0959
# Accuracy of the network on the test images: 10.28% & Test Loss: 10.12136341571808
# Train Log:Epoch: 960, Step [1/60000], TrainLoss: 0.0850
# Train Log:Epoch: 960, Step [501/60000], TrainLoss: 0.0839
# Accuracy of the network on the test images: 9.7% & Test Loss: 10.145269894599915
# Train Log:Epoch: 961, Step [1/60000], TrainLoss: 0.0702
# Train Log:Epoch: 961, Step [501/60000], TrainLoss: 0.1033
# Accuracy of the network on the test images: 9.67% & Test Loss: 10.30693609237671
# Train Log:Epoch: 962, Step [1/60000], TrainLoss: 0.0564
# Train Log:Epoch: 962, Step [501/60000], TrainLoss: 0.1416
# Accuracy of the network on the test images: 9.85% & Test Loss: 10.21243860244751
# Train Log:Epoch: 963, Step [1/60000], TrainLoss: 0.0769
# Train Log:Epoch: 963, Step [501/60000], TrainLoss: 0.0889
# Accuracy of the network on the test images: 10.16% & Test Loss: 10.097672982215881
# Train Log:Epoch: 964, Step [1/60000], TrainLoss: 0.1014
# Train Log:Epoch: 964, Step [501/60000], TrainLoss: 0.0820
# Accuracy of the network on the test images: 11.11% & Test Loss: 9.956549277305603
# Train Log:Epoch: 965, Step [1/60000], TrainLoss: 0.0487
# Train Log:Epoch: 965, Step [501/60000], TrainLoss: 0.0822
# Accuracy of the network on the test images: 9.95% & Test Loss: 10.196857461929321
# Train Log:Epoch: 966, Step [1/60000], TrainLoss: 0.0865
# Train Log:Epoch: 966, Step [501/60000], TrainLoss: 0.0677
# Accuracy of the network on the test images: 10.17% & Test Loss: 10.191661682128906
# Train Log:Epoch: 967, Step [1/60000], TrainLoss: 0.1169
# Train Log:Epoch: 967, Step [501/60000], TrainLoss: 0.0653
# Accuracy of the network on the test images: 10.34% & Test Loss: 10.169269118309021
# Train Log:Epoch: 968, Step [1/60000], TrainLoss: 0.0591
# Train Log:Epoch: 968, Step [501/60000], TrainLoss: 0.0736
# Accuracy of the network on the test images: 10.56% & Test Loss: 10.168094258308411
# Train Log:Epoch: 969, Step [1/60000], TrainLoss: 0.0647
# Train Log:Epoch: 969, Step [501/60000], TrainLoss: 0.0733
# Accuracy of the network on the test images: 9.7% & Test Loss: 10.308706312179565
# Train Log:Epoch: 970, Step [1/60000], TrainLoss: 0.0762
# Train Log:Epoch: 970, Step [501/60000], TrainLoss: 0.0915
# Accuracy of the network on the test images: 9.95% & Test Loss: 10.266629548072816
# Train Log:Epoch: 971, Step [1/60000], TrainLoss: 0.0618
# Train Log:Epoch: 971, Step [501/60000], TrainLoss: 0.1055
# Accuracy of the network on the test images: 10.16% & Test Loss: 10.200785055160523
# Train Log:Epoch: 972, Step [1/60000], TrainLoss: 0.0865
# Train Log:Epoch: 972, Step [501/60000], TrainLoss: 0.1104
# Accuracy of the network on the test images: 9.93% & Test Loss: 10.232756309509277
# Train Log:Epoch: 973, Step [1/60000], TrainLoss: 0.0999
# Train Log:Epoch: 973, Step [501/60000], TrainLoss: 0.0854
# Accuracy of the network on the test images: 10.2% & Test Loss: 10.187957615852357
# Train Log:Epoch: 974, Step [1/60000], TrainLoss: 0.0514
# Train Log:Epoch: 974, Step [501/60000], TrainLoss: 0.0824
# Accuracy of the network on the test images: 9.96% & Test Loss: 10.276768145561219
# Train Log:Epoch: 975, Step [1/60000], TrainLoss: 0.0479
# Train Log:Epoch: 975, Step [501/60000], TrainLoss: 0.0826
# Accuracy of the network on the test images: 10.16% & Test Loss: 10.332826924324035
# Train Log:Epoch: 976, Step [1/60000], TrainLoss: 0.0444
# Train Log:Epoch: 976, Step [501/60000], TrainLoss: 0.0651
# Accuracy of the network on the test images: 9.78% & Test Loss: 10.391059818267822
# Train Log:Epoch: 977, Step [1/60000], TrainLoss: 0.0623
# Train Log:Epoch: 977, Step [501/60000], TrainLoss: 0.0547
# Accuracy of the network on the test images: 9.87% & Test Loss: 10.432021532058716
# Train Log:Epoch: 978, Step [1/60000], TrainLoss: 0.0374
# Train Log:Epoch: 978, Step [501/60000], TrainLoss: 0.0603
# Accuracy of the network on the test images: 10.46% & Test Loss: 10.3231582736969
# Train Log:Epoch: 979, Step [1/60000], TrainLoss: 0.0486
# Train Log:Epoch: 979, Step [501/60000], TrainLoss: 0.1006
# Accuracy of the network on the test images: 10.48% & Test Loss: 10.277051286697388
# Train Log:Epoch: 980, Step [1/60000], TrainLoss: 0.0979
# Train Log:Epoch: 980, Step [501/60000], TrainLoss: 0.0808
# Accuracy of the network on the test images: 10.07% & Test Loss: 10.372303695678712
# Train Log:Epoch: 981, Step [1/60000], TrainLoss: 0.0667
# Train Log:Epoch: 981, Step [501/60000], TrainLoss: 0.0605
# Accuracy of the network on the test images: 9.95% & Test Loss: 10.441985216140747
# Train Log:Epoch: 982, Step [1/60000], TrainLoss: 0.0920
# Train Log:Epoch: 982, Step [501/60000], TrainLoss: 0.1082
# Accuracy of the network on the test images: 9.82% & Test Loss: 10.482276210784912
# Train Log:Epoch: 983, Step [1/60000], TrainLoss: 0.0974
# Train Log:Epoch: 983, Step [501/60000], TrainLoss: 0.0616
# Accuracy of the network on the test images: 10.59% & Test Loss: 10.285276112556458
# Train Log:Epoch: 984, Step [1/60000], TrainLoss: 0.0633
# Train Log:Epoch: 984, Step [501/60000], TrainLoss: 0.0726
# Accuracy of the network on the test images: 9.99% & Test Loss: 10.419847087860107
# Train Log:Epoch: 985, Step [1/60000], TrainLoss: 0.0902
# Train Log:Epoch: 985, Step [501/60000], TrainLoss: 0.0845
# Accuracy of the network on the test images: 10.04% & Test Loss: 10.446454191207886
# Train Log:Epoch: 986, Step [1/60000], TrainLoss: 0.0350
# Train Log:Epoch: 986, Step [501/60000], TrainLoss: 0.0647
# Accuracy of the network on the test images: 10.72% & Test Loss: 10.298424797058106
# Train Log:Epoch: 987, Step [1/60000], TrainLoss: 0.0751
# Train Log:Epoch: 987, Step [501/60000], TrainLoss: 0.0424
# Accuracy of the network on the test images: 10.31% & Test Loss: 10.415992469787598
# Train Log:Epoch: 988, Step [1/60000], TrainLoss: 0.0638
# Train Log:Epoch: 988, Step [501/60000], TrainLoss: 0.0894
# Accuracy of the network on the test images: 9.5% & Test Loss: 10.572971487045288
# Train Log:Epoch: 989, Step [1/60000], TrainLoss: 0.0624
# Train Log:Epoch: 989, Step [501/60000], TrainLoss: 0.0504
# Accuracy of the network on the test images: 9.68% & Test Loss: 10.558072290420533
# Train Log:Epoch: 990, Step [1/60000], TrainLoss: 0.0432
# Train Log:Epoch: 990, Step [501/60000], TrainLoss: 0.0985
# Accuracy of the network on the test images: 10.1% & Test Loss: 10.424230976104736
# Train Log:Epoch: 991, Step [1/60000], TrainLoss: 0.0718
# Train Log:Epoch: 991, Step [501/60000], TrainLoss: 0.0849
# Accuracy of the network on the test images: 9.97% & Test Loss: 10.458624687194824
# Train Log:Epoch: 992, Step [1/60000], TrainLoss: 0.0668
# Train Log:Epoch: 992, Step [501/60000], TrainLoss: 0.1002
# Accuracy of the network on the test images: 9.75% & Test Loss: 10.593121490478516
# Train Log:Epoch: 993, Step [1/60000], TrainLoss: 0.0670
# Train Log:Epoch: 993, Step [501/60000], TrainLoss: 0.0523
# Accuracy of the network on the test images: 10.07% & Test Loss: 10.509313712120056
# Train Log:Epoch: 994, Step [1/60000], TrainLoss: 0.0879
# Train Log:Epoch: 994, Step [501/60000], TrainLoss: 0.0610
# Accuracy of the network on the test images: 9.62% & Test Loss: 10.573233470916747
# Train Log:Epoch: 995, Step [1/60000], TrainLoss: 0.0446
# Train Log:Epoch: 995, Step [501/60000], TrainLoss: 0.0713
# Accuracy of the network on the test images: 10.21% & Test Loss: 10.504689483642577
# Train Log:Epoch: 996, Step [1/60000], TrainLoss: 0.0664
# Train Log:Epoch: 996, Step [501/60000], TrainLoss: 0.0541
# Accuracy of the network on the test images: 9.89% & Test Loss: 10.494757223129273
# Train Log:Epoch: 997, Step [1/60000], TrainLoss: 0.0467
# Train Log:Epoch: 997, Step [501/60000], TrainLoss: 0.0768
# Accuracy of the network on the test images: 10.27% & Test Loss: 10.513801913261414
# Train Log:Epoch: 998, Step [1/60000], TrainLoss: 0.0339
# Train Log:Epoch: 998, Step [501/60000], TrainLoss: 0.1139
# Accuracy of the network on the test images: 9.84% & Test Loss: 10.589638547897339
# Train Log:Epoch: 999, Step [1/60000], TrainLoss: 0.0635
# Train Log:Epoch: 999, Step [501/60000], TrainLoss: 0.0950
# Accuracy of the network on the test images: 10.8% & Test Loss: 10.565611896514893
# Train Log:Epoch: 1000, Step [1/60000], TrainLoss: 0.0703
# Train Log:Epoch: 1000, Step [501/60000], TrainLoss: 0.0626
# Accuracy of the network on the test images: 10.05% & Test Loss: 10.575093393325806
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 62
#      58 plt.ylabel("Loss")
#      59 plt.title("random labels train vs test loss",color = "green")
# ---> 62 plt.savefig('/home/dravich/Research/Plots/randomMnist2.png',
#      63             format='PNG',
#      64             dpi=300,
#      65             bbox_inches='tight')
#      66 plt.show()
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\_api\deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\backends\backend_agg.py:517, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     468 @_api.delete_parameter("3.5", "args")
#     469 def print_png(self, filename_or_obj, *args,
#     470               metadata=None, pil_kwargs=None):
#     471     """
#     472     Write the figure to a PNG file.
#     473
#    (...)
#     515         *metadata*, including the default 'Software' key.
#     516     """
# --> 517     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\backends\backend_agg.py:464, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     459 """
#     460 Draw the canvas, then save it using `.image.imsave` (to which
#     461 *pil_kwargs* and *metadata* are forwarded).
#     462 """
#     463 FigureCanvasAgg.draw(self)
# --> 464 mpl.image.imsave(
#     465     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     466     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\image.py:1664, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1662 pil_kwargs.setdefault("format", format)
#    1663 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1664 image.save(fname, **pil_kwargs)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\PIL\Image.py:2350, in Image.save(self, fp, format, **params)
#    2348         fp = builtins.open(filename, "r+b")
#    2349     else:
# -> 2350         fp = builtins.open(filename, "w+b")
#    2352 try:
#    2353     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/dravich/Research/Plots/randomMnist2.png'

# %%
#Plotting Train Vs Test Loss

plt.plot(epochArr,train_loss_arr,color="Blue")
plt.plot(epochArr,test_loss_arr,color="red")
plt.legend(['Train Loss','Test Loss'],loc="upper right")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("random labels train vs test loss",color = "green")

plt.show()
