# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torch.nn.utils import parameters_to_vector, vector_to_parameters
from torch.autograd import Variable
import tqdm as notebook_tqdm

# %%
# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=False)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

print("train_dataset size:", len(train_dataset),"\ntest_dataset size:", len(test_dataset))
# Out:
# train_dataset size: 60000
# test_dataset size: 10000

# %%
# Data loader func
def train_loader(batch_size):
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size = batch_size, 
                                           shuffle=True)
    return train_loader


def test_loader(batch_size):
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)
    return test_loader

# %%
class M1(nn.Module):
  def __init__(self,):
        super(M1, self).__init__()
        self.fc1 = nn.Linear(784, 500)
        self.fc2 = nn.Linear(500, 10)
        
  def forward(self, x):
        # flatten as one dimension
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
len(train_loader(6000))
# Out:
# 10

# %%
#train function
def trainFunc(model,num_epochs,train_batch_size,status):
    model.train()
    print('strated')
    train_load = train_loader(train_batch_size)
    n_total_steps = len(train_load)
    train_losses = []
    train_epoch = []
    train_acc = []
    not_converged =True
    epoch = 0
    trainAvgLossArr = []
    trainAvgAccArr = []

    while not_converged:
        epoch += 1
        n_correct = 0
        n_samples = 0
        lossSum =0
        totalacc =0

        for i, (images, labels) in enumerate(train_load):  
            
            images, labels = Variable(images),Variable(labels)
            # zero the parameter gradients
            optimizer.zero_grad()
            # Forward pass
            prediction = model(images)
            loss = loss_func(prediction, labels)
            lossSum += loss.detach().numpy()
            # Backward and optimize
            loss.backward()
            
            optimizer.step()

            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            acc = 100.0 * n_correct / n_samples
            totalacc += acc

            train_losses.append(loss.item())
            train_acc.append(acc)
            train_epoch.append(epoch)

            if (i+1) % status == 0:
                print (f'Train O/P: Epoch [{epoch}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}',end= '\r',flush = True)
   
                if epoch == num_epochs:
                        print("Max Epoch Reached")
                        not_converged = False
                elif (epoch > 5) and  (train_losses[-1] < 0.001):
                    if abs(train_losses[-3] - train_losses[-2]) < 1.0e-05 and abs(train_losses[-2] - train_losses[-1]) < 1.0e-05:
                        print("Convergeance reached for loss:",train_losses[-1])
                        not_converged = False

       
        epochAcc = totalacc/(i+1)
        trainAvgLossArr.append(lossSum/n_total_steps)    
        trainAvgAccArr.append(epochAcc)

    return train_epoch,train_losses,train_acc,trainAvgLossArr,trainAvgAccArr

# %%
# Training Model with batch size=64
torch.manual_seed(1)

learning_rate = 0.0015
mBatch1 = M1()
loss_func = nn.CrossEntropyLoss()
weight_decay_val = 1e-4

optimizer = torch.optim.Adam(mBatch1.parameters(), lr=learning_rate, weight_decay = weight_decay_val)

#optimizer = torch.optim.SGD(mBatch1.parameters(), lr=learning_rate)

a=[]
for i in mBatch1.parameters():
    a.append(torch.numel(i))
print(f'Total no of parameters in Model with batch_size={64} is:{np.sum(a)}')
# Out:
# Total no of parameters in Model with batch_size=64 is:397510

# %%
max_epochs = 5
train_batch_size = 64
status = 500
B1_train_epoch,B1_train_losses,B1_train_acc,B1trainAvgLossArr,B1trainAvgAccArr  = trainFunc(mBatch1,max_epochs,train_batch_size,status)
# Out:
# strated
# Max Epoch Reached[5/5], Step [500/938], Loss: 0.0577

# %%
# Training Model with batch size=1000
torch.manual_seed(1)

learning_rate = 0.0001
mBatch2 = M1()
loss_func = nn.CrossEntropyLoss()
weight_decay_val = 1e-4
optimizer = torch.optim.Adam(mBatch2.parameters(), lr=learning_rate, weight_decay=weight_decay_val) 
#optimizer = torch.optim.SGD(mBatch2.parameters(), lr=learning_rate)

a=[]
for i in mBatch2.parameters():
    a.append(torch.numel(i))
print(f'Total no of parameters in Model with batch_size={1000} is:{np.sum(a)}')
# Out:
# Total no of parameters in Model with batch_size=1000 is:397510

# %%
max_epochs = 5
train_batch_size = 1000
status = 10
B2_train_epoch,B2_train_losses,B2_train_acc,B2trainAvgLossArr,B2trainAvgAccArr = trainFunc(mBatch2,max_epochs,train_batch_size,status)
# Out:
# strated
# Max Epoch Reached[5/5], Step [10/60], Loss: 0.1285
# Max Epoch Reached[5/5], Step [20/60], Loss: 0.1469
# Max Epoch Reached[5/5], Step [30/60], Loss: 0.1588
# Max Epoch Reached[5/5], Step [40/60], Loss: 0.1800
# Max Epoch Reached[5/5], Step [50/60], Loss: 0.1666
# Max Epoch Reached[5/5], Step [60/60], Loss: 0.1508

# %%
epochArr = np.array(np.linspace(1,max_epochs,max_epochs))

# %%
#Plotting Loss plot for both Batch 1 and Batch 2 models
plt.figure(figsize=(20, 8))
plt.plot(epochArr,B1trainAvgLossArr,color="blue")
plt.plot(epochArr,B2trainAvgLossArr,color="orange")
plt.title('Batch1 & Bathc2 Loss VS Epoch')
plt.legend(['Batch 1','Batch 2'])
plt.xlabel ('Epoch')
plt.ylabel ('loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 #Plotting Loss plot for both Batch 1 and Batch 2 models
#       2 plt.figure(figsize=(20, 8))
# ----> 3 plt.plot(epochArr,B1trainAvgLossArr,color="blue")
#       4 plt.plot(epochArr,B2trainAvgLossArr,color="orange")
#       5 plt.title('Batch1 & Bathc2 Loss VS Epoch')
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\envs\Deep_Learning_HW1\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (15,) and (5,)

# %%
batch1_param = torch.nn.utils.parameters_to_vector(mBatch1.parameters())
print(batch1_param,'\nlen:',len(batch1_param))
# Out:
# tensor([ 2.6979e-38, -2.4739e-38,  3.5070e-38,  ..., -4.8440e-02,
#          1.1849e-01, -5.3866e-03], grad_fn=<CatBackward0>)
# len: 397510

# %%
batch2_param = torch.nn.utils.parameters_to_vector(mBatch2.parameters())
print(batch2_param,'\nlen:',len(batch2_param))
# Out:
# tensor([ 5.9354e-29,  2.8207e-33,  4.1796e-38,  ...,  7.1905e-02,
#         -9.5391e-02, -3.3829e-02], grad_fn=<CatBackward0>)
# len: 397510

# %%
alpha = np.linspace(-2.0, 2.0, num=31)
print(alpha)
# Out:
# [-2.         -1.86666667 -1.73333333 -1.6        -1.46666667 -1.33333333
#  -1.2        -1.06666667 -0.93333333 -0.8        -0.66666667 -0.53333333
#  -0.4        -0.26666667 -0.13333333  0.          0.13333333  0.26666667
#   0.4         0.53333333  0.66666667  0.8         0.93333333  1.06666667
#   1.2         1.33333333  1.46666667  1.6         1.73333333  1.86666667
#   2.        ]

# %%
thetaArr =[]
for i in range (len(alpha)):
    theta = (1-alpha[i])*batch1_param + alpha[i]*batch2_param
    thetaArr.append(theta)

# %%
def testFunction(model,loss_func,testLoader,test_batch_size): 
    test_loader = testLoader
    test_load = test_loader(test_batch_size)
    model.eval()
    with torch.no_grad():
        n_correct = 0
        n_samples = 0
        testLoss = 0
        count =0
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
            
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
            # max returns (value ,index)
            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            count +=1

    netTest_loss = testLoss/count
    netTest_acc1 = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the test images: {netTest_acc1} & Test Loss: {netTest_loss} %', end="\r", flush= True)
    return netTest_acc1, netTest_loss

# %%
import copy

# %%
modelsTrainEpochArr = []
modelsTrainLossArr = []
modelsTrainAccArr = []
modelsTestLossArr = []
modelsTestAccArr = []

for i in range (len(thetaArr)):
    #torch.manual_seed(1)
    
    j=copy.deepcopy(i) 
    theta = (1-alpha[i])*batch1_param + alpha[i]*batch2_param
    j = M1()
    torch.nn.utils.vector_to_parameters(theta,j.parameters())
    loss_func = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(j.parameters(), lr=0.0004, weight_decay = 1e-4)
    

    a=[]
    for k in j.parameters():
        a.append(torch.numel(k))
    print(f'Total no of parameters in Model Theta {i} is:{np.sum(a)}')

    print(j.parameters)

    max_epochs = 1
    train_batch_size = 500
    status = 100
    T_train_epoch,T_train_losses,T_train_acc,T_trainAvgLossArr,T_trainAvgAccArr = trainFunc(j,max_epochs,train_batch_size,status)
    
    
    
    modelsTrainLossArr.append(T_trainAvgLossArr)
    modelsTrainAccArr.append(T_trainAvgAccArr)
    
    test_batch_size=500
    T_acc, T_testLoss = testFunction(j,loss_func,test_loader,test_batch_size)
    modelsTestAccArr.append(T_acc)
    modelsTestLossArr.append(T_testLoss)
# Out:
# Total no of parameters in Model Theta 0 is:397510
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0409
# Total no of parameters in Model Theta 1 is:397510 & Test Loss: 0.19692172885261244 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0909
# Total no of parameters in Model Theta 2 is:397510 & Test Loss: 0.18211988249386196 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0390
# Total no of parameters in Model Theta 3 is:397510 & Test Loss: 0.1642434465815313 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0273
# Total no of parameters in Model Theta 4 is:397510 & Test Loss: 0.1482393308862811 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0219
# Total no of parameters in Model Theta 5 is:397510 & Test Loss: 0.13444924755604007 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0141
# Total no of parameters in Model Theta 6 is:397510 & Test Loss: 0.12080293867038563 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0215
# Total no of parameters in Model Theta 7 is:397510& Test Loss: 0.10835284981876611 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0146
# Total no of parameters in Model Theta 8 is:397510 & Test Loss: 0.09861755102174356 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0233
# Total no of parameters in Model Theta 9 is:397510 & Test Loss: 0.08705790939275175 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0253
# Total no of parameters in Model Theta 10 is:397510& Test Loss: 0.07979337956057861 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0105
# Total no of parameters in Model Theta 11 is:397510& Test Loss: 0.0723646278376691 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0060
# Total no of parameters in Model Theta 12 is:397510& Test Loss: 0.06603813751135021 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0150
# Total no of parameters in Model Theta 13 is:397510& Test Loss: 0.06019194102846086 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0168
# Total no of parameters in Model Theta 14 is:397510& Test Loss: 0.05563890468329191 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0243
# Total no of parameters in Model Theta 15 is:397510& Test Loss: 0.053863289579749105 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0281
# Total no of parameters in Model Theta 16 is:397510& Test Loss: 0.05330808886792511 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0316
# Total no of parameters in Model Theta 17 is:397510& Test Loss: 0.05409351130947471 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0368
# Total no of parameters in Model Theta 18 is:397510& Test Loss: 0.05813853787258268 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0331
# Total no of parameters in Model Theta 19 is:397510& Test Loss: 0.06657235799357294 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0579
# Total no of parameters in Model Theta 20 is:397510& Test Loss: 0.07908318433910608 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.0916
# Total no of parameters in Model Theta 21 is:397510& Test Loss: 0.09393213093280792 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1266
# Total no of parameters in Model Theta 22 is:397510& Test Loss: 0.11741728633642197 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1312
# Total no of parameters in Model Theta 23 is:397510& Test Loss: 0.138918277900666 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1517
# Total no of parameters in Model Theta 24 is:397510& Test Loss: 0.1509789819829166 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1201
# Total no of parameters in Model Theta 25 is:397510& Test Loss: 0.15672858012840152 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1914
# Total no of parameters in Model Theta 26 is:397510 Test Loss: 0.16380376722663642 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.2251
# Total no of parameters in Model Theta 27 is:397510& Test Loss: 0.16646694829687475 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1894
# Total no of parameters in Model Theta 28 is:397510& Test Loss: 0.1777533977292478 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.1507
# Total no of parameters in Model Theta 29 is:397510& Test Loss: 0.19398464653640984 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.2335
# Total no of parameters in Model Theta 30 is:397510& Test Loss: 0.22535163648426532 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [100/120], Loss: 0.3233
# Accuracy of the network on the test images: 92.26 & Test Loss: 0.272294987924397 %

# %%
def meanScore(dataArr):
    meanModelData = []
    for i in range (len(dataArr)):
        meanScore = np.mean(dataArr[i])
        meanModelData.append(meanScore)
    return meanModelData

def minScore(dataArr):
    minModelScore = []
    for i in range (len(dataArr)):
        minScore = np.mean(dataArr[i])
        minModelScore.append(minScore)
    return minModelScore

def maxScore(dataArr):
    maxModelScore = []
    for i in range (len(dataArr)):
        maxScore = np.max(dataArr[i])
        maxModelScore.append(maxScore)
    return maxModelScore

# %%
fig,ax=plt.subplots()
ax.plot(alpha,(modelsTrainLossArr),color="Blue",linestyle='dashed', marker="o")
ax.plot(alpha,modelsTestLossArr,color="Blue", marker="v")
ax.legend(['Train Loss','Test Loss'],loc="center left")
ax.set_xlabel("Alpha",color="Green")
ax.set_ylabel("CrossEntropy Loss",color = "blue")


ax2=ax.twinx()
ax2.plot(alpha,(modelsTrainAccArr),color="red",linestyle='dashed', marker="o")
ax2.plot(alpha,modelsTestAccArr,color="red", marker="v")
ax2.set_xlabel("Alpha",color="Green")
ax2.set_ylabel("Accuracy",color = "red")
ax2.legend(['Train Acc','Test Acc'],loc="upper right")

plt.show()

# %%
# Training Model with batch size=600 and Lr 1e-3
torch.manual_seed(1)

learning_rate = 1e-3
mLr1 = M1()
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mLr1.parameters(), lr=learning_rate) 

a=[]
for i in mLr1.parameters():
    a.append(torch.numel(i))
print(f'Total no of parameters in Model with Lr={learning_rate} is:{np.sum(a)}')
# Out:
# Total no of parameters in Model with Lr=0.001 is:397510

# %%
max_epochs = 5
train_batch_size = 64
status = 10
L1_train_epoch,L1_train_losses,L1_train_acc,L1_trainAvgLossArr,L1_trainAvgAccArr  = trainFunc(mLr1,max_epochs,train_batch_size,status)
# Out:
# strated
# Max Epoch Reached[5/5], Step [10/938], Loss: 0.01777
# Max Epoch Reached[5/5], Step [20/938], Loss: 0.0226
# Max Epoch Reached[5/5], Step [30/938], Loss: 0.0846
# Max Epoch Reached[5/5], Step [40/938], Loss: 0.0410
# Max Epoch Reached[5/5], Step [50/938], Loss: 0.0101
# Max Epoch Reached[5/5], Step [60/938], Loss: 0.0182
# Max Epoch Reached[5/5], Step [70/938], Loss: 0.0531
# Max Epoch Reached[5/5], Step [80/938], Loss: 0.0644
# Max Epoch Reached[5/5], Step [90/938], Loss: 0.0633
# Max Epoch Reached[5/5], Step [100/938], Loss: 0.0229
# Max Epoch Reached[5/5], Step [110/938], Loss: 0.0039
# Max Epoch Reached[5/5], Step [120/938], Loss: 0.0356
# Max Epoch Reached[5/5], Step [130/938], Loss: 0.0325
# Max Epoch Reached[5/5], Step [140/938], Loss: 0.0387
# Max Epoch Reached[5/5], Step [150/938], Loss: 0.0468
# Max Epoch Reached[5/5], Step [160/938], Loss: 0.0265
# Max Epoch Reached[5/5], Step [170/938], Loss: 0.0201
# Max Epoch Reached[5/5], Step [180/938], Loss: 0.0347
# Max Epoch Reached[5/5], Step [190/938], Loss: 0.0088
# Max Epoch Reached[5/5], Step [200/938], Loss: 0.0226
# Max Epoch Reached[5/5], Step [210/938], Loss: 0.0061
# Max Epoch Reached[5/5], Step [220/938], Loss: 0.0071
# Max Epoch Reached[5/5], Step [230/938], Loss: 0.1369
# Max Epoch Reached[5/5], Step [240/938], Loss: 0.0119
# Max Epoch Reached[5/5], Step [250/938], Loss: 0.0167
# Max Epoch Reached[5/5], Step [260/938], Loss: 0.0287
# Max Epoch Reached[5/5], Step [270/938], Loss: 0.0146
# Max Epoch Reached[5/5], Step [280/938], Loss: 0.0304
# Max Epoch Reached[5/5], Step [290/938], Loss: 0.0714
# Max Epoch Reached[5/5], Step [300/938], Loss: 0.1212
# Max Epoch Reached[5/5], Step [310/938], Loss: 0.0774
# Max Epoch Reached[5/5], Step [320/938], Loss: 0.0400
# Max Epoch Reached[5/5], Step [330/938], Loss: 0.0724
# Max Epoch Reached[5/5], Step [340/938], Loss: 0.0375
# Max Epoch Reached[5/5], Step [350/938], Loss: 0.0161
# Max Epoch Reached[5/5], Step [360/938], Loss: 0.0325
# Max Epoch Reached[5/5], Step [370/938], Loss: 0.0958
# Max Epoch Reached[5/5], Step [380/938], Loss: 0.0340
# Max Epoch Reached[5/5], Step [390/938], Loss: 0.0037
# Max Epoch Reached[5/5], Step [400/938], Loss: 0.1490
# Max Epoch Reached[5/5], Step [410/938], Loss: 0.0092
# Max Epoch Reached[5/5], Step [420/938], Loss: 0.0133
# Max Epoch Reached[5/5], Step [430/938], Loss: 0.0163
# Max Epoch Reached[5/5], Step [440/938], Loss: 0.0708
# Max Epoch Reached[5/5], Step [450/938], Loss: 0.0053
# Max Epoch Reached[5/5], Step [460/938], Loss: 0.0576
# Max Epoch Reached[5/5], Step [470/938], Loss: 0.0160
# Max Epoch Reached[5/5], Step [480/938], Loss: 0.0990
# Max Epoch Reached[5/5], Step [490/938], Loss: 0.0027
# Max Epoch Reached[5/5], Step [500/938], Loss: 0.0445
# Max Epoch Reached[5/5], Step [510/938], Loss: 0.0534
# Max Epoch Reached[5/5], Step [520/938], Loss: 0.0381
# Max Epoch Reached[5/5], Step [530/938], Loss: 0.0092
# Max Epoch Reached[5/5], Step [540/938], Loss: 0.1086
# Max Epoch Reached[5/5], Step [550/938], Loss: 0.0123
# Max Epoch Reached[5/5], Step [560/938], Loss: 0.0131
# Max Epoch Reached[5/5], Step [570/938], Loss: 0.0901
# Max Epoch Reached[5/5], Step [580/938], Loss: 0.0264
# Max Epoch Reached[5/5], Step [590/938], Loss: 0.0650
# Max Epoch Reached[5/5], Step [600/938], Loss: 0.0117
# Max Epoch Reached[5/5], Step [610/938], Loss: 0.0284
# Max Epoch Reached[5/5], Step [620/938], Loss: 0.1798
# Max Epoch Reached[5/5], Step [630/938], Loss: 0.0174
# Max Epoch Reached[5/5], Step [640/938], Loss: 0.0238
# Max Epoch Reached[5/5], Step [650/938], Loss: 0.0218
# Max Epoch Reached[5/5], Step [660/938], Loss: 0.0564
# Max Epoch Reached[5/5], Step [670/938], Loss: 0.0430
# Max Epoch Reached[5/5], Step [680/938], Loss: 0.0219
# Max Epoch Reached[5/5], Step [690/938], Loss: 0.0780
# Max Epoch Reached[5/5], Step [700/938], Loss: 0.0317
# Max Epoch Reached[5/5], Step [710/938], Loss: 0.0398
# Max Epoch Reached[5/5], Step [720/938], Loss: 0.0435
# Max Epoch Reached[5/5], Step [730/938], Loss: 0.0115
# Max Epoch Reached[5/5], Step [740/938], Loss: 0.0105
# Max Epoch Reached[5/5], Step [750/938], Loss: 0.0144
# Max Epoch Reached[5/5], Step [760/938], Loss: 0.0249
# Max Epoch Reached[5/5], Step [770/938], Loss: 0.0081
# Max Epoch Reached[5/5], Step [780/938], Loss: 0.0209
# Max Epoch Reached[5/5], Step [790/938], Loss: 0.0414
# Max Epoch Reached[5/5], Step [800/938], Loss: 0.0158
# Max Epoch Reached[5/5], Step [810/938], Loss: 0.0091
# Max Epoch Reached[5/5], Step [820/938], Loss: 0.0131
# Max Epoch Reached[5/5], Step [830/938], Loss: 0.0219
# Max Epoch Reached[5/5], Step [840/938], Loss: 0.0491
# Max Epoch Reached[5/5], Step [850/938], Loss: 0.1250
# Max Epoch Reached[5/5], Step [860/938], Loss: 0.0200
# Max Epoch Reached[5/5], Step [870/938], Loss: 0.0394
# Max Epoch Reached[5/5], Step [880/938], Loss: 0.0418
# Max Epoch Reached[5/5], Step [890/938], Loss: 0.0184
# Max Epoch Reached[5/5], Step [900/938], Loss: 0.0070
# Max Epoch Reached[5/5], Step [910/938], Loss: 0.0550
# Max Epoch Reached[5/5], Step [920/938], Loss: 0.0227
# Max Epoch Reached[5/5], Step [930/938], Loss: 0.0035

# %%
Lr1_param = torch.nn.utils.parameters_to_vector(mLr1.parameters())
print(Lr1_param,'\nlen:',len(Lr1_param))
# Out:
# tensor([ 0.0184, -0.0158, -0.0069,  ..., -0.0040,  0.0336, -0.0238],
#        grad_fn=<CatBackward0>)
# len: 397510

# %%
# Training Model with batch size=600 and Lr 1e-2
torch.manual_seed(1)
learning_rate = 1e-2
mLr2 = M1()
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mLr2.parameters(), lr=learning_rate) 

a=[]
for i in mLr2.parameters():
    a.append(torch.numel(i))
print(f'Total no of parameters in Model with Lr={learning_rate} is:{np.sum(a)}')
# Out:
# Total no of parameters in Model with Lr=0.01 is:397510

# %%
max_epochs = 5
train_batch_size = 64
status = 10
L2_train_epoch,L2_train_losses,L2_train_acc,L2_trainAvgLossArr,L2_trainAvgAccArr  = trainFunc(mLr2,max_epochs,train_batch_size,status)
# Out:
# strated
# Max Epoch Reached[5/5], Step [10/938], Loss: 0.01806
# Max Epoch Reached[5/5], Step [20/938], Loss: 0.0047
# Max Epoch Reached[5/5], Step [30/938], Loss: 0.0554
# Max Epoch Reached[5/5], Step [40/938], Loss: 0.1324
# Max Epoch Reached[5/5], Step [50/938], Loss: 0.0399
# Max Epoch Reached[5/5], Step [60/938], Loss: 0.0376
# Max Epoch Reached[5/5], Step [70/938], Loss: 0.1355
# Max Epoch Reached[5/5], Step [80/938], Loss: 0.1512
# Max Epoch Reached[5/5], Step [90/938], Loss: 0.0271
# Max Epoch Reached[5/5], Step [100/938], Loss: 0.0351
# Max Epoch Reached[5/5], Step [110/938], Loss: 0.0350
# Max Epoch Reached[5/5], Step [120/938], Loss: 0.0405
# Max Epoch Reached[5/5], Step [130/938], Loss: 0.0905
# Max Epoch Reached[5/5], Step [140/938], Loss: 0.0327
# Max Epoch Reached[5/5], Step [150/938], Loss: 0.0353
# Max Epoch Reached[5/5], Step [160/938], Loss: 0.1557
# Max Epoch Reached[5/5], Step [170/938], Loss: 0.0036
# Max Epoch Reached[5/5], Step [180/938], Loss: 0.0981
# Max Epoch Reached[5/5], Step [190/938], Loss: 0.0614
# Max Epoch Reached[5/5], Step [200/938], Loss: 0.3032
# Max Epoch Reached[5/5], Step [210/938], Loss: 0.0337
# Max Epoch Reached[5/5], Step [220/938], Loss: 0.0302
# Max Epoch Reached[5/5], Step [230/938], Loss: 0.3074
# Max Epoch Reached[5/5], Step [240/938], Loss: 0.1514
# Max Epoch Reached[5/5], Step [250/938], Loss: 0.2545
# Max Epoch Reached[5/5], Step [260/938], Loss: 0.0416
# Max Epoch Reached[5/5], Step [270/938], Loss: 0.0618
# Max Epoch Reached[5/5], Step [280/938], Loss: 0.2544
# Max Epoch Reached[5/5], Step [290/938], Loss: 0.2118
# Max Epoch Reached[5/5], Step [300/938], Loss: 0.2739
# Max Epoch Reached[5/5], Step [310/938], Loss: 0.0925
# Max Epoch Reached[5/5], Step [320/938], Loss: 0.1567
# Max Epoch Reached[5/5], Step [330/938], Loss: 0.1985
# Max Epoch Reached[5/5], Step [340/938], Loss: 0.0781
# Max Epoch Reached[5/5], Step [350/938], Loss: 0.0551
# Max Epoch Reached[5/5], Step [360/938], Loss: 0.0266
# Max Epoch Reached[5/5], Step [370/938], Loss: 0.2814
# Max Epoch Reached[5/5], Step [380/938], Loss: 0.0614
# Max Epoch Reached[5/5], Step [390/938], Loss: 0.0090
# Max Epoch Reached[5/5], Step [400/938], Loss: 0.1025
# Max Epoch Reached[5/5], Step [410/938], Loss: 0.0055
# Max Epoch Reached[5/5], Step [420/938], Loss: 0.0600
# Max Epoch Reached[5/5], Step [430/938], Loss: 0.0328
# Max Epoch Reached[5/5], Step [440/938], Loss: 0.2620
# Max Epoch Reached[5/5], Step [450/938], Loss: 0.0716
# Max Epoch Reached[5/5], Step [460/938], Loss: 0.0672
# Max Epoch Reached[5/5], Step [470/938], Loss: 0.0057
# Max Epoch Reached[5/5], Step [480/938], Loss: 0.1036
# Max Epoch Reached[5/5], Step [490/938], Loss: 0.0005
# Max Epoch Reached[5/5], Step [500/938], Loss: 0.1867
# Max Epoch Reached[5/5], Step [510/938], Loss: 0.0224
# Max Epoch Reached[5/5], Step [520/938], Loss: 0.0137
# Max Epoch Reached[5/5], Step [530/938], Loss: 0.0059
# Max Epoch Reached[5/5], Step [540/938], Loss: 0.4134
# Max Epoch Reached[5/5], Step [550/938], Loss: 0.0745
# Max Epoch Reached[5/5], Step [560/938], Loss: 0.0074
# Max Epoch Reached[5/5], Step [570/938], Loss: 0.3212
# Max Epoch Reached[5/5], Step [580/938], Loss: 0.0131
# Max Epoch Reached[5/5], Step [590/938], Loss: 0.1183
# Max Epoch Reached[5/5], Step [600/938], Loss: 0.0061
# Max Epoch Reached[5/5], Step [610/938], Loss: 0.0126
# Max Epoch Reached[5/5], Step [620/938], Loss: 0.4166
# Max Epoch Reached[5/5], Step [630/938], Loss: 0.0926
# Max Epoch Reached[5/5], Step [640/938], Loss: 0.0500
# Max Epoch Reached[5/5], Step [650/938], Loss: 0.0603
# Max Epoch Reached[5/5], Step [660/938], Loss: 0.0231
# Max Epoch Reached[5/5], Step [670/938], Loss: 0.1015
# Max Epoch Reached[5/5], Step [680/938], Loss: 0.1983
# Max Epoch Reached[5/5], Step [690/938], Loss: 0.0361
# Max Epoch Reached[5/5], Step [700/938], Loss: 0.0574
# Max Epoch Reached[5/5], Step [710/938], Loss: 0.1021
# Max Epoch Reached[5/5], Step [720/938], Loss: 0.1810
# Max Epoch Reached[5/5], Step [730/938], Loss: 0.0662
# Max Epoch Reached[5/5], Step [740/938], Loss: 0.0817
# Max Epoch Reached[5/5], Step [750/938], Loss: 0.0159
# Max Epoch Reached[5/5], Step [760/938], Loss: 0.0075
# Max Epoch Reached[5/5], Step [770/938], Loss: 0.1705
# Max Epoch Reached[5/5], Step [780/938], Loss: 0.0545
# Max Epoch Reached[5/5], Step [790/938], Loss: 0.0307
# Max Epoch Reached[5/5], Step [800/938], Loss: 0.1042
# Max Epoch Reached[5/5], Step [810/938], Loss: 0.0557
# Max Epoch Reached[5/5], Step [820/938], Loss: 0.0246
# Max Epoch Reached[5/5], Step [830/938], Loss: 0.0575
# Max Epoch Reached[5/5], Step [840/938], Loss: 0.1097
# Max Epoch Reached[5/5], Step [850/938], Loss: 0.3494
# Max Epoch Reached[5/5], Step [860/938], Loss: 0.0821
# Max Epoch Reached[5/5], Step [870/938], Loss: 0.4136
# Max Epoch Reached[5/5], Step [880/938], Loss: 0.3111
# Max Epoch Reached[5/5], Step [890/938], Loss: 0.0247
# Max Epoch Reached[5/5], Step [900/938], Loss: 0.0895
# Max Epoch Reached[5/5], Step [910/938], Loss: 0.1344
# Max Epoch Reached[5/5], Step [920/938], Loss: 0.0602
# Max Epoch Reached[5/5], Step [930/938], Loss: 0.0092

# %%
epochArr = np.array(np.linspace(1,max_epochs,max_epochs))

# %%
#Plotting Loss plot for both Batch 1 and Batch 2 models
plt.figure(figsize=(20, 8))
plt.plot(epochArr,L1_trainAvgLossArr,color="blue")
plt.plot(epochArr,L2_trainAvgLossArr,color="orange")
plt.title('Lr1 & Lr2 Loss VS Epoch',color="green")
plt.legend(['LR1:1e-3 1','LR2:1e-2'])
plt.xlabel ('Epoch')
plt.ylabel ('loss')
plt.show()

# %%
Lr2_param = torch.nn.utils.parameters_to_vector(mLr2.parameters())
print(Lr2_param,'\nlen:',len(Lr2_param))
# Out:
# tensor([ 0.0184, -0.0158, -0.0069,  ..., -1.0895,  1.5860,  0.1025],
#        grad_fn=<CatBackward0>)
# len: 397510

# %%
modelsTrainEpochArr2 = []
modelsTrainLossArr2 = []
modelsTrainAccArr2 = []
modelsTestLossArr2 = []
modelsTestAccArr2 = []

for i in range (len(thetaArr)):
    torch.manual_seed(1)
    j=copy.deepcopy(i) 
    theta = (1-alpha[i])*Lr1_param + alpha[i]*Lr2_param
    j = M1()
    torch.nn.utils.vector_to_parameters(theta,j.parameters())
    loss_func = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(j.parameters(), lr=1e-3) #,weight_decay = 0.025)

    a=[]
    for k in j.parameters():
        a.append(torch.numel(k))
    print(f'Total no of parameters in Model Theta {i} is:{np.sum(a)}')

    print(j.parameters)

    max_epochs = 1
    train_batch_size = 1000
    status = 60
    T2_train_epoch,T2_train_losses,T2_train_acc,T2_trainAvgLossArr,T2_trainAvgAccArr = trainFunc(j,max_epochs,train_batch_size,status) #trainFunc(mBatch1,max_epochs,train_batch_size)
    
    
    #modelsTrainEpochArr2.append(T2_trainAvgLossArr)
    modelsTrainLossArr2.append(T2_trainAvgLossArr)
    modelsTrainAccArr2.append(T2_trainAvgAccArr)
    
    test_batch_size=1000
    T2_acc,T2_testLoss = testFunction(j,loss_func,test_loader,test_batch_size)
    modelsTestAccArr2.append(T2_acc)
    modelsTestLossArr2.append(T2_testLoss)
# Out:
# Total no of parameters in Model Theta 0 is:397510
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 115.0115
# Total no of parameters in Model Theta 1 is:397510 & Test Loss: 115.21305465698242 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 89.7354
# Total no of parameters in Model Theta 2 is:397510 & Test Loss: 89.61806945800781 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 67.8077
# Total no of parameters in Model Theta 3 is:397510 & Test Loss: 67.74223861694335 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 50.8148
# Total no of parameters in Model Theta 4 is:397510 & Test Loss: 51.08083801269531 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 39.7983
# Total no of parameters in Model Theta 5 is:397510 & Test Loss: 40.344552993774414 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 32.1864
# Total no of parameters in Model Theta 6 is:397510 & Test Loss: 32.03295974731445 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 22.8784
# Total no of parameters in Model Theta 7 is:397510 & Test Loss: 22.758581829071044 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 15.2044
# Total no of parameters in Model Theta 8 is:397510 & Test Loss: 15.75325117111206 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 9.6228
# Total no of parameters in Model Theta 9 is:397510 & Test Loss: 10.210458612442016 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 5.9421
# Total no of parameters in Model Theta 10 is:397510& Test Loss: 6.237630224227905 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 3.4833
# Total no of parameters in Model Theta 11 is:397510& Test Loss: 3.573435640335083 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 1.6343
# Total no of parameters in Model Theta 12 is:397510& Test Loss: 1.7588760256767273 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.7012
# Total no of parameters in Model Theta 13 is:397510& Test Loss: 0.8140498280525208 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.2612
# Total no of parameters in Model Theta 14 is:397510& Test Loss: 0.3451667085289955 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0658
# Total no of parameters in Model Theta 15 is:397510& Test Loss: 0.12559860721230506 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0155
# Total no of parameters in Model Theta 16 is:397510& Test Loss: 0.056595414550974964 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0305
# Total no of parameters in Model Theta 17 is:397510& Test Loss: 0.061165521293878554 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0356
# Total no of parameters in Model Theta 18 is:397510& Test Loss: 0.0657144065015018 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0328
# Total no of parameters in Model Theta 19 is:397510& Test Loss: 0.07000405825674534 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0342
# Total no of parameters in Model Theta 20 is:397510& Test Loss: 0.07639189977198839 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0351
# Total no of parameters in Model Theta 21 is:397510 Test Loss: 0.08849656339734793 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0348
# Total no of parameters in Model Theta 22 is:397510& Test Loss: 0.10422806106507779 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0370
# Total no of parameters in Model Theta 23 is:397510& Test Loss: 0.1260184045881033 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0422
# Total no of parameters in Model Theta 24 is:397510& Test Loss: 0.1540191400796175 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0519
# Total no of parameters in Model Theta 25 is:397510& Test Loss: 0.18762853294610976 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0674
# Total no of parameters in Model Theta 26 is:397510& Test Loss: 0.22723324298858644 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.0888
# Total no of parameters in Model Theta 27 is:397510& Test Loss: 0.2731372430920601 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.1170
# Total no of parameters in Model Theta 28 is:397510& Test Loss: 0.3258594162762165 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.1526
# Total no of parameters in Model Theta 29 is:397510& Test Loss: 0.38475178480148314 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.1947
# Total no of parameters in Model Theta 30 is:397510& Test Loss: 0.4508818119764328 %
# <bound method Module.parameters of M1(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )>
# strated
# Max Epoch Reached[1/1], Step [60/60], Loss: 0.2433
# Accuracy of the network on the test images: 96.52 & Test Loss: 0.5250072911381721 %

# %%
fig,ax=plt.subplots()
ax.plot(alpha,(modelsTrainLossArr2),color="Blue",linestyle='dashed', marker="o")
ax.plot(alpha,modelsTestLossArr2,color="Blue", marker="v")
ax.legend(['Train Loss','Test Loss'],loc="center left")
ax.set_xlabel("Alpha",color="Green")
ax.set_ylabel("CrossEntropy Loss",color = "blue")
ax.set_title("learning rate 1e-3 vs. 1e-2",color = "green")


ax2=ax.twinx()
ax2.plot(alpha,(modelsTrainAccArr2),color="red",linestyle='dashed', marker="o")
ax2.plot(alpha,modelsTestAccArr2,color="red", marker="v")
ax2.set_xlabel("Alpha",color="Green")
ax2.set_ylabel("Accuracy",color = "red")
ax2.legend(['Train Acc','Test Acc'],loc="upper right")

plt.show()
